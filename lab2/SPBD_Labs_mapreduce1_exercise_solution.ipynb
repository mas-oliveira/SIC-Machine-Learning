# %% [markdown]
# <a href="https://colab.research.google.com/github/mas-oliveira/SIC-Machine-Learning/blob/main/lab2/SPBD_Labs_mapreduce1_exercise_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install Hadoop on Google Colab
# !curl -s https://raw.githubusercontent.com/smduarte/spbd-2324/main/lab1/install_hadoop.sh | bash

# %% [markdown]
# # Python MapReduce Exercise
#
# In the notebook, you should create a map-reduce program that counts the number of occurrences of each word.
#
# In this exercise, hadoop runs in standalone mode and reads data from the local filesystem.

# %% [markdown]
# ### Download the dataset

# %%
# !wget -q -O os_maias.txt https://www.dropbox.com/s/n24v0z7y79np319/os_maias.txt?dl=0

# %% [markdown]
# ## WordCount Example
# Read the words from input and count the number of occurrences of each word.

# %% [markdown]
# ### Mapper
# Complete with the code for the mapper.

# %%
# %%file mapper_words.py
#!/usr/bin/env python

# import sys
import sys
# import string library function
import string

# input comes from STDIN (standard input)
for line in sys.stdin:
    # remove leading and trailing whitespace
    line = line.strip()
    # remove punctuation characters
    line = line.translate(str.maketrans('', '', string.punctuation+'«»'))
    # split the line into words
    words = line.split()
    for w in words:
        print('%s\t1' % w)
# Out:
# Writing mapper_words.py

# %% [markdown]
# ### Reducer

# %%
# %%file reducer_words.py
#!/usr/bin/env python

import sys

lastWord = None
lastCounter = 0;

# input comes from STDIN
for line in sys.stdin:
    # remove leading and trailing whitespace
    line = line.strip()

    # parse the input we got from mapper.py
    word, count = line.split('\t', 1)

    # convert count (currently a string) to int
    count = int(count)

    if word != lastWord:
        if lastWord:
            print('%s\t%d' % (lastWord, lastCounter))
        lastWord = word
        lastCounter = count
    else:
        lastCounter += count

if lastWord:
    print('%s\t%d' % (lastWord, lastCounter))
# Out:
# Writing reducer_words.py

# %% [markdown]
# ### Hadoop standalone mode execution

# %% [markdown]
# The output directory needs to be cleared...

# %%
# !rm -rf results_words

# %% [markdown]
# #### Submitting the job
#
# The _hadoop_ command is used to submit the mapreduce job to the cluster...

# %%
# !hadoop jar /usr/local/hadoop-3.3.6/share/hadoop/tools/lib/hadoop-*streaming*.jar -files mapper_words.py,reducer_words.py -mapper mapper_words.py -reducer reducer_words.py -input os_maias.txt -output results_words
# Out:
# 2023-09-20 14:50:57,392 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2023-09-20 14:50:57,703 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2023-09-20 14:50:57,703 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2023-09-20 14:50:57,740 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-09-20 14:50:58,332 INFO mapred.FileInputFormat: Total input files to process : 1
# 2023-09-20 14:50:58,383 INFO mapreduce.JobSubmitter: number of splits:1
# 2023-09-20 14:50:59,155 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1995652993_0001
# 2023-09-20 14:50:59,155 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2023-09-20 14:51:00,037 INFO mapred.LocalDistributedCacheManager: Localized file:/content/mapper_words.py as file:/tmp/hadoop-root/mapred/local/job_local1995652993_0001_d5719a48-1e5f-4404-8862-ce1203f26366/mapper_words.py
# 2023-09-20 14:51:00,083 INFO mapred.LocalDistributedCacheManager: Localized file:/content/reducer_words.py as file:/tmp/hadoop-root/mapred/local/job_local1995652993_0001_0065b7e3-6f0c-490a-87b6-c4547a9003e5/reducer_words.py
# 2023-09-20 14:51:00,324 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2023-09-20 14:51:00,327 INFO mapreduce.Job: Running job: job_local1995652993_0001
# 2023-09-20 14:51:00,331 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2023-09-20 14:51:00,342 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2023-09-20 14:51:00,356 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-09-20 14:51:00,356 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-09-20 14:51:00,449 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2023-09-20 14:51:00,457 INFO mapred.LocalJobRunner: Starting task: attempt_local1995652993_0001_m_000000_0
# 2023-09-20 14:51:00,500 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-09-20 14:51:00,502 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-09-20 14:51:00,568 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-09-20 14:51:00,603 INFO mapred.MapTask: Processing split: file:/content/os_maias.txt:0+1292368
# 2023-09-20 14:51:00,634 INFO mapred.MapTask: numReduceTasks: 1
# 2023-09-20 14:51:00,715 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-09-20 14:51:00,715 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-09-20 14:51:00,716 INFO mapred.MapTask: soft limit at 83886080
# 2023-09-20 14:51:00,716 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-09-20 14:51:00,716 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-09-20 14:51:00,721 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-09-20 14:51:00,728 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_words.py]
# 2023-09-20 14:51:00,733 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2023-09-20 14:51:00,736 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2023-09-20 14:51:00,736 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2023-09-20 14:51:00,737 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2023-09-20 14:51:00,737 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2023-09-20 14:51:00,738 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2023-09-20 14:51:00,740 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2023-09-20 14:51:00,740 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2023-09-20 14:51:00,740 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2023-09-20 14:51:00,741 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2023-09-20 14:51:00,742 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2023-09-20 14:51:00,743 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2023-09-20 14:51:00,779 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:00,780 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:00,787 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:00,861 INFO streaming.PipeMapRed: Records R/W=532/1
# 2023-09-20 14:51:00,884 INFO streaming.PipeMapRed: R/W/S=1000/452/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:01,342 INFO mapreduce.Job: Job job_local1995652993_0001 running in uber mode : false
# 2023-09-20 14:51:01,345 INFO mapreduce.Job:  map 0% reduce 0%
# 2023-09-20 14:51:01,408 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-09-20 14:51:01,409 INFO streaming.PipeMapRed: mapRedFinished
# 2023-09-20 14:51:01,413 INFO mapred.LocalJobRunner:
# 2023-09-20 14:51:01,414 INFO mapred.MapTask: Starting flush of map output
# 2023-09-20 14:51:01,414 INFO mapred.MapTask: Spilling map output
# 2023-09-20 14:51:01,414 INFO mapred.MapTask: bufstart = 0; bufend = 1653351; bufvoid = 104857600
# 2023-09-20 14:51:01,414 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25360964(101443856); length = 853433/6553600
# 2023-09-20 14:51:02,045 INFO mapred.MapTask: Finished spill 0
# 2023-09-20 14:51:02,062 INFO mapred.Task: Task:attempt_local1995652993_0001_m_000000_0 is done. And is in the process of committing
# 2023-09-20 14:51:02,066 INFO mapred.LocalJobRunner: Records R/W=532/1
# 2023-09-20 14:51:02,066 INFO mapred.Task: Task 'attempt_local1995652993_0001_m_000000_0' done.
# 2023-09-20 14:51:02,076 INFO mapred.Task: Final Counters for attempt_local1995652993_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=1434808
# 		FILE: Number of bytes written=2866920
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=5877
# 		Map output records=213359
# 		Map output bytes=1653351
# 		Map output materialized bytes=2080075
# 		Input split bytes=78
# 		Combine input records=0
# 		Spilled Records=213359
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=340787200
# 	File Input Format Counters
# 		Bytes Read=1292368
# 2023-09-20 14:51:02,076 INFO mapred.LocalJobRunner: Finishing task: attempt_local1995652993_0001_m_000000_0
# 2023-09-20 14:51:02,076 INFO mapred.LocalJobRunner: map task executor complete.
# 2023-09-20 14:51:02,080 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2023-09-20 14:51:02,082 INFO mapred.LocalJobRunner: Starting task: attempt_local1995652993_0001_r_000000_0
# 2023-09-20 14:51:02,102 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-09-20 14:51:02,102 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-09-20 14:51:02,103 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-09-20 14:51:02,111 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@716c732f
# 2023-09-20 14:51:02,114 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-09-20 14:51:02,145 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2382574336, maxSingleShuffleLimit=595643584, mergeThreshold=1572499072, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-09-20 14:51:02,164 INFO reduce.EventFetcher: attempt_local1995652993_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-09-20 14:51:02,205 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1995652993_0001_m_000000_0 decomp: 2080071 len: 2080075 to MEMORY
# 2023-09-20 14:51:02,213 INFO reduce.InMemoryMapOutput: Read 2080071 bytes from map-output for attempt_local1995652993_0001_m_000000_0
# 2023-09-20 14:51:02,222 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2080071, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->2080071
# 2023-09-20 14:51:02,229 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2023-09-20 14:51:02,230 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2023-09-20 14:51:02,231 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2023-09-20 14:51:02,238 INFO mapred.Merger: Merging 1 sorted segments
# 2023-09-20 14:51:02,238 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 2080067 bytes
# 2023-09-20 14:51:02,348 INFO mapreduce.Job:  map 100% reduce 0%
# 2023-09-20 14:51:02,427 INFO reduce.MergeManagerImpl: Merged 1 segments, 2080071 bytes to disk to satisfy reduce memory limit
# 2023-09-20 14:51:02,428 INFO reduce.MergeManagerImpl: Merging 1 files, 2080075 bytes from disk
# 2023-09-20 14:51:02,429 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2023-09-20 14:51:02,429 INFO mapred.Merger: Merging 1 sorted segments
# 2023-09-20 14:51:02,430 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 2080067 bytes
# 2023-09-20 14:51:02,431 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2023-09-20 14:51:02,440 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reducer_words.py]
# 2023-09-20 14:51:02,445 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-09-20 14:51:02,448 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2023-09-20 14:51:02,476 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:02,477 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:02,479 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:02,503 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:02,578 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:02,611 INFO streaming.PipeMapRed: Records R/W=16574/1
# 2023-09-20 14:51:02,936 INFO streaming.PipeMapRed: R/W/S=100000/8967/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:03,231 INFO streaming.PipeMapRed: R/W/S=200000/19000/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:03,317 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-09-20 14:51:03,324 INFO streaming.PipeMapRed: mapRedFinished
# 2023-09-20 14:51:03,326 INFO mapred.Task: Task:attempt_local1995652993_0001_r_000000_0 is done. And is in the process of committing
# 2023-09-20 14:51:03,328 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2023-09-20 14:51:03,328 INFO mapred.Task: Task attempt_local1995652993_0001_r_000000_0 is allowed to commit now
# 2023-09-20 14:51:03,330 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1995652993_0001_r_000000_0' to file:/content/results_words
# 2023-09-20 14:51:03,331 INFO mapred.LocalJobRunner: Records R/W=16574/1 > reduce
# 2023-09-20 14:51:03,331 INFO mapred.Task: Task 'attempt_local1995652993_0001_r_000000_0' done.
# 2023-09-20 14:51:03,332 INFO mapred.Task: Final Counters for attempt_local1995652993_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=5594990
# 		FILE: Number of bytes written=5201332
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=22673
# 		Reduce shuffle bytes=2080075
# 		Reduce input records=213359
# 		Reduce output records=22673
# 		Spilled Records=213359
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=29
# 		Total committed heap usage (bytes)=340787200
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=254337
# 2023-09-20 14:51:03,332 INFO mapred.LocalJobRunner: Finishing task: attempt_local1995652993_0001_r_000000_0
# 2023-09-20 14:51:03,332 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2023-09-20 14:51:03,349 INFO mapreduce.Job:  map 100% reduce 100%
# 2023-09-20 14:51:03,349 INFO mapreduce.Job: Job job_local1995652993_0001 completed successfully
# 2023-09-20 14:51:03,411 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=7029798
# 		FILE: Number of bytes written=8068252
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=5877
# 		Map output records=213359
# 		Map output bytes=1653351
# 		Map output materialized bytes=2080075
# 		Input split bytes=78
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=22673
# 		Reduce shuffle bytes=2080075
# 		Reduce input records=213359
# 		Reduce output records=22673
# 		Spilled Records=426718
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=29
# 		Total committed heap usage (bytes)=681574400
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=1292368
# 	File Output Format Counters
# 		Bytes Written=254337
# 2023-09-20 14:51:03,411 INFO streaming.StreamJob: Output directory: results_words

# %% [markdown]
# #### Checking the results
# The result is stored in directory results.

# %%
# !cat results_words/part-*
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# praticar	1
# praticas	1
# pratico	8
# praticável	1
# prato	23
# pratos	10
# praxes	1
# prazer	25
# prazeres	3
# praça	18
# praças	2
# precata	1
# precaução	2
# precauções	1
# preceito	1
# preceptor	2
# preciosa	5
# preciosamente	3
# preciosidade	2
# preciosidades	4
# precioso	3
# precipitada	1
# precipitadamente	6
# precipitandose	2
# precipitara	1
# precipitarse	1
# precipitava	1
# precipitação	1
# precipitouse	4
# precisa	10
# precisado	1
# precisamente	2
# precisamos	3
# precisando	1
# precisas	2
# precisava	9
# precisavam	3
# precisavase	1
# preciso	8
# precisos	2
# precisou	1
# precisão	3
# precoce	1
# preconceitos	1
# precursor	1
# predestinado	1
# prefere	1
# preferem	1
# preferia	9
# preferiam	1
# preferido	1
# preferiria	4
# preferiu	1
# preferível	5
# prefiro	3
# prega	2
# pregada	3
# pregadas	1
# pregados	1
# pregalhe	1
# pregando	2
# pregar	3
# pregas	6
# pregavam	1
# preghiera	1
# prego	6
# pregou	1
# preguiça	9
# preguiçando	2
# preguiças	2
# preguiçavam	1
# preguiçosa	4
# preguiçosamente	7
# preguiçoso	1
# pregões	1
# prejudicarao	1
# prejudicava	1
# prejudicavaa	1
# prejuízos	1
# prelado	5
# premio	3
# prenda	6
# prendada	1
# prendam	1
# prendas	4
# prende	2
# prendendose	2
# prender	5
# prendera	1
# prenderamse	1
# prenderia	1
# prenderse	1
# prendia	4
# prendiam	3
# prendiase	1
# prendiaselhe	1
# prenunciava	1
# preocupada	1
# preocupado	3
# preocupação	4
# preopinante	1
# prepara	1
# preparada	4
# preparado	7
# preparados	1
# preparalo	1
# preparando	9
# preparandose	2
# preparar	5
# preparara	4
# prepararalhe	1
# prepararam	1
# prepararse	1
# prepararvos	1
# preparativos	1
# preparava	4
# preparavase	1
# preparação	2
# preparouse	3
# presa	8
# presas	1
# presbiteriana	1
# presbítero	1
# presenciara	2
# presentarte	1
# presente	5
# presentes	4
# presentinho	1
# presença	11
# preserverassem	1
# presidente	5
# presidia	1
# presidindo	2
# preso	5
# presos	2
# pressa	41
# pressagiam	1
# pressagiava	1
# pressentia	1
# pressentimento	2
# pressentira	1
# presságio	1
# pressões	1
# presta	1
# prestações	1
# prestei	1
# prestigioso	1
# prestígio	1
# presumido	1
# presunto	1
# presídios	1
# preta	21
# pretas	11
# pretenciosas	1
# pretenciosos	1
# pretendendo	1
# pretendia	3
# pretensiosa	2
# pretensiosas	1
# pretensão	1
# pretexto	11
# preto	67
# pretos	10
# prevalecer	1
# preveniao	1
# prevenilo	1
# prevenisse	1
# prevenção	1
# previra	2
# previsões	1
# prezam	1
# prezavase	1
# preço	3
# preços	1
# prima	1
# primadona	1
# primaria	1
# primas	1
# primavera	11
# primeira	55
# primeiramente	1
# primeiras	14
# primeiro	83
# primeiros	16
# primitivas	1
# primo	8
# primor	1
# princesa	5
# principais	1
# principalmente	2
# principio	22
# principiou	3
# princípios	4
# priori	1
# prisioneiro	1
# prisão	3
# privar	1
# privara	1
# privações	1
# privilegio	2
# proas	1
# probidade	1
# problemas	2
# procedendo	2
# procedimento	1
# procissão	5
# procissões	1
# proclamada	1
# proclamar	2
# proclamavase	1
# proclamei	1
# procura	2
# procurado	4
# procurador	46
# procuralo	1
# procurando	16
# procurandoa	1
# procurar	17
# procurara	5
# procurarte	2
# procurava	22
# procuravam	4
# procure	2
# procurou	6
# procuroua	1
# prodigalidade	2
# prodigalizado	1
# prodigalizando	1
# prodigamente	1
# prodigiosa	2
# prodigiosamente	1
# prodigioso	8
# productos	1
# produz	1
# produziam	1
# produzir	2
# produzira	1
# prodígio	2
# profanado	1
# profanação	2
# profano	1
# profecia	2
# proferiu	1
# profissionalmente	1
# profissão	4
# profissões	2
# profond	1
# profonde	1
# profunda	12
# profundamente	15
# profundas	4
# profundidade	4
# profundidades	3
# profundo	21
# profundos	3
# profusa	2
# profusão	2
# proféticas	1
# profético	1
# programa	8
# programas	1
# progressista	3
# progressivas	1
# progresso	17
# progressos	2
# proibido	2
# proibirlhe	1
# proibirte	1
# projectavase	1
# projecto	4
# projectos	1
# proletárias	1
# proletário	1
# prolixas	1
# prolongadamente	1
# prolongado	2
# prolongandose	1
# prolongar	1
# prolongara	1
# prolongação	1
# prolongouse	1
# promessa	8
# promessas	2
# promete	1
# prometedora	1
# prometendo	4
# prometer	1
# prometera	3
# prometeralho	1
# prometeu	2
# prometeulhe	2
# prometeunos	1
# prometia	3
# prometida	1
# prometido	1
# prometilhe	1
# promiscuidade	1
# promovi	1
# promovida	1
# pronta	4
# prontamente	1
# prontas	1
# pronto	9
# prontos	2
# pronunciar	3
# pronunciara	1
# pronunciaria	1
# pronunciava	2
# pronuncie	1
# pronunciouse	1
# propaganda	1
# propicia	1
# propondo	1
# proponho	1
# propor	1
# proporção	1
# proporções	3
# proposta	1
# propriamente	2
# propriedade	7
# propriedades	3
# proprietário	4
# propuser	1
# propusera	1
# propósito	25
# propôs	3
# propôslhe	1
# prosa	10
# prospera	1
# prosperando	1
# prosperar	1
# prosperidade	2
# prosperidades	1
# prosseguia	2
# prosseguir	1
# prosseguiu	5
# prostituta	2
# prostitutas	1
# prostrada	2
# prostram	1
# prostrara	1
# prostração	1
# prostíbulos	1
# protagonista	1
# protection	1
# protectora	3
# protecção	2
# proteger	2
# protegidos	1
# protestado	1
# protestando	1
# protestante	2
# protestantismo	1
# protestar	1
# protestaram	1
# protestava	1
# protesto	3
# protestos	3
# protestou	13
# prova	4
# provada	1
# provado	2
# provalo	1
# provando	3
# provandolhe	1
# provar	5
# provas	9
# provasse	1
# provassem	1
# provava	2
# provavalhe	1
# provavam	1
# provação	1
# proveito	1
# provenientes	1
# proventos	1
# proverbe	1
# providamente	1
# providencial	6
# providencialmente	1
# providenciar	1
# provinciana	2
# provinciano	3
# provinha	4
# provinham	1
# provisão	1
# provocando	1
# provocante	1
# provocação	2
# provocações	1
# provou	3
# provouo	1
# provável	6
# provém	2
# província	13
# províncias	3
# proximidade	1
# prudement	1
# prudente	4
# prudentemente	2
# pruderie	1
# prudência	2
# prussianos	4
# prédio	7
# prédios	5
# prémio	1
# príncipe	23
# própria	20
# próprias	3
# próprio	26
# próprios	5
# próxima	2
# próximo	2
# psicológica	1
# publica	12
# publicada	1
# publicado	3
# publicamente	6
# publicar	8
# publicara	1
# publicas	3
# publicasse	1
# publicava	1
# publicação	3
# publicidade	3
# publico	7
# publicou	1
# publiquem	1
# puchada	1
# pude	5
# puder	1
# pudera	5
# puderam	1
# pudesse	19
# pudessem	3
# pudicícia	1
# pudim	1
# pudor	8
# pudores	1
# pueril	6
# puerilidade	2
# pueris	2
# pugnei	1
# pujante	2
# pujantes	1
# pulando	3
# pular	1
# pularlhe	1
# pulava	4
# pulha	6
# pulhamente	1
# pulhas	3
# pulhice	2
# pulhices	1
# pulinhos	4
# pulmão	2
# pulmões	1
# pulo	4
# pulos	3
# pulou	8
# puloulhe	1
# pulseira	1
# pulseiras	1
# pulso	6
# pulsos	3
# pulverisação	1
# punch	4
# puncheira	1
# pungente	1
# pungentes	1
# pungir	1
# punha	15
# punhada	1
# punhadas	1
# punhado	2
# punhais	1
# punham	11
# punhao	1
# punhase	2
# punho	4
# punhos	18
# punível	1
# pupilas	3
# pur	1
# pura	9
# puramente	2
# puras	2
# pureza	5
# purifica	2
# purificadora	1
# purificando	1
# purificasse	1
# puritana	1
# puritano	2
# puritanos	2
# puro	12
# puros	1
# pus	7
# pusera	8
# puseralhe	1
# puseram	1
# pusessem	1
# puxado	2
# puxando	13
# puxandoo	2
# puxar	5
# puxara	2
# puxarem	1
# puxava	3
# puxavalhe	1
# puxavam	2
# puxavamno	1
# puxavao	1
# puxou	10
# puxoulhe	4
# puxouo	3
# puxão	9
# puxãosinho	1
# puxões	3
# pálida	16
# pálidas	1
# pálido	48
# pálidos	5
# pálpebra	2
# pálpebras	8
# pára	1
# pássaro	4
# pássaros	5
# pátio	18
# pátios	1
# pátria	9
# pátrias	1
# pândega	2
# pândegas	1
# pânico	1
# pâté	1
# pão	14
# pé	155
# péla	2
# pérfida	2
# pérfidas	1
# pérola	7
# pérolas	1
# pés	67
# pésinho	3
# pésinhos	5
# péssima	2
# péssimo	1
# pétala	1
# pêlos	3
# pêra	5
# pêsame	1
# pêsames	2
# pílulas	1
# píncaros	1
# pó	16
# póda	1
# pólvora	3
# pós	2
# pôde	32
# pôla	3
# pôlo	1
# pôr	26
# pôrme	1
# pôrse	1
# pôs	10
# pôslhe	2
# pôsme	1
# pôsse	3
# põe	7
# põem	1
# põeme	1
# põeno	1
# põese	2
# põeseme	1
# públicos	1
# púdica	1
# púdico	1
# púlpito	2
# púrpura	2
# pústula	1
# pútrida	1
# quadrado	3
# quadrados	3
# quadrilha	1
# quadrilhado	1
# quadrilhados	1
# quadrilhas	1
# quadrinhas	1
# quadrinho	1
# quadris	2
# quadro	11
# quadros	6
# quadrosinho	1
# quais	2
# qual	23
# qualidade	1
# qualidades	3
# qualquer	31
# quand	1
# quando	328
# quanta	3
# quantas	5
# quantias	1
# quantidade	5
# quanto	60
# quarenta	4
# quarentona	1
# quarta	1
# quarto	171
# quartos	27
# quasi	163
# quatro	50
# quatrocentas	1
# quatrocentos	3
# que	4986
# quebrada	1
# quebradas	2
# quebrado	7
# quebrando	1
# quebrantada	1
# quebranto	4
# quebrar	8
# quebrara	1
# quebraram	1
# quebrarseiam	1
# quebras	1
# quebrassem	1
# quebrava	2
# quebravalhe	1
# quebrote	1
# quebrou	3
# queda	5
# quedo	2
# queen	1
# queijadas	8
# queijo	2
# queimado	4
# queimala	1
# queimar	2
# queimava	1
# queira	6
# queixa	1
# queixandose	3
# queixar	2
# queixarase	2
# queixas	4
# queixase	3
# queixava	3
# queixavamse	1
# queixavase	5
# queixo	13
# queixos	1
# queixouse	9
# queixumes	1
# quelque	1
# quem	158
# quente	32
# quentes	4
# quentura	1
# quer	35
# quereis	1
# querem	6
# queremos	1
# queremse	1
# querendo	24
# querer	18
# quereria	3
# quererá	2
# queres	26
# queria	104
# queriam	5
# queriao	3
# querias	3
# queriase	2
# queriate	1
# querida	13
# querido	22
# queridos	2
# querme	1
# quernos	1
# quero	35
# querote	1
# querubim	1
# questão	37
# questões	13
# qui	2
# quid	1
# quidam	1
# quieta	7
# quietação	7
# quietinha	1
# quietinhos	1
# quieto	5
# quila	1
# quinhentas	4
# quinhentos	2
# quinta	84
# quintais	1
# quintal	16
# quintalejo	2
# quintarola	1
# quintarolas	2
# quintas	5
# quinze	15
# quinzena	2
# quiosque	10
# quis	56
# quiser	10
# quisera	11
# quiserao	1
# quiserem	1
# quiseres	4
# quisermos	1
# quisesse	10
# quisesses	2
# quislhe	1
# quisse	3
# quon	1
# quê	29
# química	2
# químico	1
# químicos	2
# ra	1
# rabino	2
# rabiosque	1
# rabiscando	1
# rabiscava	1
# rabiças	1
# rabo	1
# rabona	2
# rachada	1
# rachadas	1
# rachado	1
# rachar	2
# racharte	1
# rachasse	1
# raciocínio	1
# raciocínios	1
# racionalismo	1
# racionalista	1
# radiante	37
# radiantes	2
# radicais	2
# radiosa	2
# rafeiro	3
# raiada	1
# rainha	2
# raio	8
# raios	5
# raiva	3
# raivosamente	1
# raiz	1
# raizes	2
# rajada	6
# rajadas	2
# rala	3
# ralhando	2
# ralé	1
# rama	2
# ramagem	2
# ramagens	15
# ramalhavam	1
# ramalhetes	2
# ramaria	2
# ramarias	1
# ramas	2
# raminho	1
# raminhos	1
# ramo	22
# ramos	23
# rampa	8
# rancho	8
# rancor	8
# rancores	3
# rancoroso	1
# rangente	1
# ranger	3
# rangeu	3
# rangia	1
# rangiam	1
# rantantans	1
# rantatans	1
# rapada	1
# rapados	1
# rapagão	3
# rapagões	1
# rapariga	25
# raparigas	9
# rapariguinha	2
# rapariguita	1
# rapaz	103
# rapazes	54
# rapaziada	6
# rapazinho	1
# rapazito	1
# rapazola	3
# rapazote	2
# rapidamente	11
# rapé	5
# raquítico	4
# rara	7
# raramente	2
# raras	4
# rareavamlhe	1
# raridades	1
# raro	8
# raros	3
# rascunhara	1
# rascunhava	3
# rascunho	6
# rascunhos	1
# rasgada	2
# rasgadamente	5
# rasgadas	1
# rasgado	7
# rasgando	1
# rasgassem	1
# rasgo	6
# rasgos	1
# rasgões	2
# raso	1
# raspando	3
# raspar	2
# rasparam	1
# raspava	1
# raspome	1
# rastaquouère	2
# rastaquouèros	1
# rasteiras	1
# rastejando	1
# rastejante	1
# rastilho	1
# rastro	1
# rato	1
# ratão	2
# ravissant	1
# razoável	3
# razão	67
# razões	7
# raça	18
# raças	6
# ração	1
# reabilitaria	1
# reabotoou	1
# reaccionário	1
# readormecer	1
# reagir	1
# reagiu	1
# reais	3
# real	26
# realejo	3
# realidade	12
# realismo	8
# realista	7
# realizadas	1
# realizando	1
# realizar	4
# realizara	1
# realizava	1
# realização	1
# realizáveis	1
# realizável	1
# realmente	59
# realçada	2
# realçava	1
# reanimavase	1
# reanimou	1
# reaparece	2
# reaparecendo	1
# reaparecer	2
# reaparecesse	1
# reapareceu	4
# reaparecia	2
# reaparição	1
# reassumiu	1
# reatando	1
# rebaixamento	1
# rebanho	1
# rebate	1
# rebates	1
# rebeca	2
# rebecas	2
# rebelde	1
# rebeldes	4
# rebentada	1
# rebentamos	1
# rebentando	1
# rebentar	2
# rebentava	3
# rebente	1
# rebentou	1
# rebentões	1
# rebocada	1
# rebocado	1
# rebolando	1
# rebolandose	1
# rebordo	5
# rebrilhando	1
# rebrilharam	2
# rebrilhava	3
# rebrilhavam	3
# rebrilhou	1
# rebuliço	2
# rebus	2
# rebuscando	1
# rebuscar	1
# rebuscava	1
# rebuçados	1
# rebuço	1
# recado	6
# recados	3
# recaia	1
# recaialhe	1
# recaindo	1
# recair	1
# recaiu	2
# recalcando	2
# recalcou	2
# recamada	1
# recamado	2
# recambiada	1
# recanto	16
# recantos	5
# recantosinho	1
# recapitular	2
# recatadas	1
# recato	2
# recaíra	1
# recaíram	1
# receando	4
# recear	1
# receava	5
# receavam	1
# receba	1
# recebe	3
# recebem	1
# recebemos	1
# recebendo	8
# receber	15
# recebera	12
# receberam	1
# receberao	1
# receberem	1
# recebeu	5
# recebeulhe	1
# recebi	3
# recebia	8
# recebida	3
# recebido	2
# recebo	1
# receia	1
# receio	10
# receita	7
# receitando	1
# receitar	2
# receitas	1
# recentemente	2
# receou	4
# recheio	1
# rechonchuda	1
# rechonchudos	1
# recibo	2
# recinto	9
# recipe	1
# reciprocando	1
# recita	2
# recitando	1
# recitar	7
# recitas	1
# recitativo	2
# recitava	1
# recitavam	1
# recitavaos	1
# recitou	1
# recivilizado	1
# reclamados	1
# reclamar	1
# reclamara	2
# reclamasse	1
# reclamava	2
# reclamavao	1
# reclamações	1
# reclamo	1
# reclamou	3
# reclinada	1
# reclinado	1
# reclinandose	1
# reclusa	1
# recoberta	2
# recobertas	3
# recoberto	1
# recobria	3
# recolhendo	2
# recolher	16
# recolhera	1
# recolheraa	1
# recolheram	5
# recolheramse	1
# recolherem	1
# recolherse	2
# recolhesse	3
# recolheu	7
# recolheuse	1
# recolhi	1
# recolhia	12
# recolhiam	2
# recolhida	3
# recolhidas	1
# recolhido	5
# recolhidos	1
# recolhimento	2
# recomecei	1
# recomendado	1
# recomendandolhe	1
# recomendaralhe	1
# recomendavalhe	2
# recomendações	2
# recomendote	1
# recomendou	2
# recomendoulhe	1
# recomeça	1
# recomeçado	2
# recomeçando	3
# recomeçar	1
# recomeçara	7
# recomeçaram	1
# recomeçavase	1
# recomeçou	15
# recompensados	1
# recompor	1
# reconciliados	1
# reconciliação	8
# reconfortalo	1
# reconfortando	1
# reconfortar	1
# reconfortarse	1
# reconhecelo	1
# reconhecer	3
# reconhecera	2
# reconhecerse	1
# reconhecerte	1
# reconhecesse	1
# reconheceu	9
# reconheceulhes	1
# reconheceuo	2
# reconheci	1
# reconhecia	4
# reconhecido	2
# reconhecimento	2
# reconheço	2
# reconstruilo	1
# recontando	1
# recontara	1
# recontro	1
# recordados	1
# recordando	3
# recordandose	3
# recordar	3
# recordara	1
# recordarse	1
# recordava	8
# recordavam	1
# recordavase	3
# recordação	3
# recordações	10
# recordo	1
# recordou	1
# recordouse	4
# recortados	2
# recortalas	1
# recortando	1
# recostada	2
# recostado	5
# recostados	1
# recostarse	1
# recostos	1
# recostouse	1
# recreio	1
# recrescialhe	1
# recrimina	1
# recriminar	1
# recriminação	1
# recriminações	3
# recta	3
# rectidão	1
# rectificando	1
# rectificar	1
# rectificou	1
# recto	1
# recuado	1
# recuando	5
# recuar	1
# recuava	1
# recubans	1
# recuou	9
# recuperar	1
# recuperares	1
# recurso	1
# recursos	1
# recurvas	2
# recurvo	1
# recusa	1
# recusandose	1
# recusar	1
# recusaram	1
# recusarase	1
# recusava	2
# recusavalhe	1
# recuse	1
# recusou	5
# recusoulha	1
# recusouse	2
# redacteur	1
# redactor	3
# redacção	9
# rede	3
# redemoinhar	2
# redes	2
# redige	1
# redigi	1
# redigirem	1
# redigiu	1
# redijo	1
# redoma	1
# redominava	1
# redomoinhava	1
# redonda	7
# redondinha	1
# redondinho	1
# redondo	4
# redondos	3
# redor	49
# reduziase	1
# reduzida	1
# reduzir	1
# reduziu	1
# reenchendo	1
# reentrando	1
# reentrar	2
# reentrava	1
# refazendo	1
# refazer	2
# referese	1
# referência	1
# refinado	1
# reflechi	1
# reflectidamente	2
# reflectido	1
# reflectidos	1
# reflectindo	5
# reflectir	5
# reflectira	2
# reflectiu	4
# reflexo	6
# reflexos	5
# reflexão	2
# reflexões	1
# reflorescia	1
# reforma	4
# reformas	2
# reforçado	1
# reforçaram	1
# refracção	2
# refregas	1
# refrescado	1
# refrescando	1
# refrescar	2
# refrescava	1
# refrescavase	1
# refresco	1
# refrescou	1
# refugiada	2
# refugiado	1
# refugiados	1
# refugiandose	4
# refugiar	1
# refugiara	1
# refugiarse	5
# refugiavase	2
# refugio	1
# refugiou	1
# refugiouse	3
# refulge	1
# refulgentes	2
# refulgia	1
# refulgiam	1
# refulgiram	1
# refulgiu	1
# refulgência	1
# refundir	2
# refúgio	1
# rega	1
# regado	1
# regador	1
# regaladamente	3
# regalado	1
# regalar	1
# regalase	1
# regalo	3
# regalou	1
# regalouse	1
# regando	1
# regantes	1
# regar	1
# regatas	1
# regateei	1
# regato	1
# regatos	1
# regaço	17
# regelada	3
# regeladamente	1
# regeladas	2
# regelado	2
# regeladora	1
# regelados	1
# regelava	2
# regelavam	1
# regenera	1
# regenerador	1
# regeneradora	1
# regiamente	5
# regime	9
# regimento	1
# regimentos	1
# registo	1
# registos	1
# região	1
# regiões	2
# regozijo	1
# regra	2
# regras	5
# regressado	1
# regressar	2
# regressava	1
# reguapa	1
# regular	2
# regularmente	1
# regulasse	1
# regulava	1
# regulavam	1
# rei	19
# reinado	3
# reinava	2
# reine	1
# reino	14
# reinos	2
# reis	16
# reitre	1
# rejeitara	1
# rejuvenescia	1
# relacionavamse	1
# relambidos	1
# relambória	1
# relance	6
# relancear	1
# relanceara	1
# relancearam	1
# relanceou	1
# relativamente	1
# relativas	1
# relatório	3
# relaxação	1
# relação	1
# relações	21
# relembra	1
# relembrando	2
# relembrou	3
# relendo	2
# reler	1
# reles	20
# releu	1
# relevo	10
# relevos	1
# relia	3
# relido	2
# religiosa	10
# religiosamente	2
# religiosas	3
# religiosidade	1
# religioso	1
# religiosos	2
# religião	8
# religiões	1
# reluzente	3
# reluzentes	1
# reluzia	12
# reluziam	2
# reluzindo	4
# reluzir	2
# reluziu	1
# reluziulhe	1
# relva	23
# relvas	3
# relâmpago	3
# relâmpagos	1
# relíquia	5
# relíquias	1
# relógio	45
# remanso	2
# remar	2
# rematando	1
# remate	5
# rememorado	1
# remendos	1
# remergulhava	1
# remergulhou	2
# remessa	1
# remeta	1
# remetendo	2
# remetendolhe	1
# remeterlhe	1
# remeteu	1
# remeteuo	1
# remexendo	6
# remexer	6
# remexera	2
# remexeu	2
# remexia	3
# remexiam	1
# remobilada	1
# remobilar	1
# remoer	2
# remoinhou	1
# remonta	3
# remontado	1
# remontar	1
# remontei	1
# remorso	4
# remorsos	5
# remota	2
# remotas	1
# remoto	2
# remoçada	1
# remoçar	2
# remoçasse	1
# remoçava	1
# remédio	4
# remédios	2
# renascer	1
# renascesse	1
# renascimento	2
# renda	22
# rendas	19
# render	1
# rendezvous	5
# rendida	1
# rendido	2
# rendilhado	1
# rendimento	3
# rendimentos	1
# rendinha	1
# renegado	2
# renovado	1
# renovar	1
# renovara	1
# renque	5
# renques	2
# rente	7
# renunciar	1
# reocupara	2
# reocupou	1
# reorganizar	1
# repagar	1
# repara	2
# reparando	1
# reparar	2
# reparara	3
# reparaste	1
# reparação	4
# reparou	8
# repartida	1
# repartição	3
# repas	6
# repassada	1
# repassadas	1
# repassado	2
# repassados	1
# repassar	1
# repassavam	1
# repatriado	1
# repelindo	2
# repelir	2
# repelira	1
# repeliu	1
# repeliua	1
# repeliuo	1
# repelão	7
# repelões	2
# repente	130
# repentina	1
# repentino	2
# repercorreu	1
# repetia	11
# repetiam	2
# repetida	2
# repetidamente	2
# repetidas	2
# repetido	2
# repetilohia	1
# repetindo	5
# repetir	1
# repetira	1
# repetiram	1
# repetisse	2
# repetiu	8
# repetição	2
# repicava	1
# repicavam	1
# repicou	1
# repintados	1
# repique	3
# repisar	1
# repita	1
# replicava	1
# replicou	9
# repoltreado	1
# repoltreouse	1
# reportórios	1
# repossuir	1
# reposteiro	50
# reposteiros	7
# repousando	1
# repousandolhe	1
# repousante	1
# repousar	1
# repousava	1
# repouso	6
# repreender	2
# repreendesse	1
# repreendeua	1
# repreendiao	1
# repreensivo	1
# repreensão	3
# representa	1
# representado	1
# representam	1
# representando	7
# representante	2
# representar	1
# representava	2
# representação	2
# represália	1
# reprimir	1
# reprovado	1
# reprovável	1
# reps	21
# republicano	5
# republicanos	3
# repuchos	2
# repugnava	1
# repugnavalhe	1
# repugnoulhe	1
# repugnância	4
# repulsivo	1
# repulsão	1
# reputação	2
# repuxado	2
# repuxo	3
# repuxos	1
# repuxou	1
# república	5
# requebrando	1
# requebro	1
# requebros	1
# requentando	1
# requintadas	1
# requintado	3
# requintava	1
# requinte	8
# requintes	6
# rescendendo	1
# rescendente	1
# reserva	5
# reservada	1
# reservado	5
# reservados	1
# reservava	1
# resfolegava	1
# resfolgar	1
# resguardado	1
# resguardados	1
# resguardando	1
# resguardava	1
# resguardavam	1
# resguardo	1
# residência	6
# residências	1
# resignada	2
# resignadamente	2
# resignado	3
# resignava	2
# resignação	5
# resinas	1
# resistente	2
# resisti	1
# resistia	1
# resistindo	1
# resistir	1
# resistira	1
# resistiria	1
# resistiu	1
# resistência	5
# resmungando	2
# resmungar	2
# resmungava	2
# resmungou	4
# resmungão	2
# resoluto	2
# resolução	5
# resoluções	1
# resolve	1
# resolvendo	1
# resolvendose	1
# resolver	1
# resolvera	3
# resolveu	2
# resolvi	1
# resolviam	1
# resolviase	1
# resolvida	1
# resolvidas	1
# respeita	2
# respeitabilidade	2
# respeitada	1
# respeitado	1
# respeitar	1
# respeitas	1
# respeitava	1
# respeitavaa	1
# respeito	30
# respeitos	4
# respeitosa	1
# respeitosamente	9
# respeitoso	1
# respeitoulhe	1
# respeitável	4
# respira	1
# respirando	9
# respirar	12
# respiraram	1
# respirase	1
# respirava	3
# respiravam	1
# respiração	3
# respirou	6
# respirálo	1
# resplandecendo	1
# resplandecente	9
# resplandecentes	1
# resplandecer	3
# resplandeceram	1
# resplandecia	10
# resplandeciam	3
# resplendor	2
# respondas	1
# responde	1
# respondendo	2
# responder	12
# respondera	3
# responderam	1
# respondeu	61
# respondi	1
# respondia	7
# respondialhe	1
# respondiam	2
# respondido	1
# responsabilidade	5
# responsabilidades	3
# responsabilité	1
# responsáveis	1
# responsável	1
# resposta	12
# ressaltar	3
# ressaltava	3
# ressaltou	1
# ressalvar	1
# ressentem	1
# ressentido	1
# ressentimento	2
# ressentiu	1
# ressequidas	1
# ressequido	2
# ressequindo	1
# ressoantes	1
# ressoar	3
# ressoaram	2
# ressoavam	3
# ressonava	3
# ressoou	4
# ressudando	1
# ressurgia	1
# ressurgido	2
# ressurgir	1
# ressurgiu	2
# ressurreição	1
# ressuscita	1
# ressuscitar	1
# resta	6
# restabelecer	1
# restabelecida	1
# restabelecido	1
# restar	1
# restaria	1
# restaurante	1
# restava	10
# restavam	5
# restavamlhe	1
# restituindolhe	1
# restituir	1
# restituirlhos	1
# restituísse	1
# resto	91
# restos	7
# resulta	1
# resultado	7
# resultando	1
# resultou	1
# resumia	1
# resumindo	1
# resumiu	7
# resumo	9
# resumos	1
# resvalando	1
# resvalara	1
# resvalava	2
# resvalou	1
# retardada	1
# retardado	2
# retardando	1
# retardaram	1
# retardasse	1
# retardou	1
# retardouse	1
# retemperarnos	1
# retendoa	1
# retendoo	1
# reter	3
# retesadas	1
# retesados	1
# retesando	1
# reteso	1
# reteve	1
# reteveo	1
# reteveos	1
# reticência	1
# reticências	1
# retidas	1
# retido	3
# retinha	1
# retinham	1
# retinia	1
# retiniu	5
# retinta	1
# retintas	1
# retira	1
# retirada	4
# retirado	5
# retirados	1
# retirandolho	1
# retirar	4
# retirara	3
# retiraramse	1
# retirarse	2
# retirasse	1
# retirava	1
# retiravase	1
# retiro	10
# retirouse	2
# retocar	2
# retocava	1
# retomado	3
# retomando	2
# retomandolhe	1
# retomar	1
# retomara	2
# retomará	1
# retomou	5
# retoque	2
# retoques	7
# retorce	1
# retorcendo	2
# retorcendose	1
# retorcer	1
# retorcido	1
# retortas	1
# retracta	1
# retractarse	1
# retrairse	2
# retrato	22
# retratos	11
# retratosinho	1
# retroceder	1
# retrocedera	1
# retrocedeu	3
# retrós	1
# retumbantemente	1
# retumbar	1
# retumbavam	1
# retumbou	1
# retêla	1
# retórica	4
# retórico	1
# reumatismo	4
# reumatismos	2
# reunia	1
# reunindo	1
# reunir	3
# reuniram	1
# reuniremse	2
# reunirnos	1
# reunirse	1
# reunião	2
# reuniões	2
# revelada	1
# reveladoras	2
# revelando	3
# revelar	2
# revelara	1
# revelaralhe	1
# revelaram	1
# revelarase	1
# revelarse	1
# revelasse	1
# revelava	5
# revelavam	2
# revelação	9
# revelações	5
# revelou	1
# revendo	2
# rever	1
# reverberações	1
# reverenciar	1
# reverendo	10
# reverendos	1
# reverente	1
# revestida	2
# revestido	2
# revestidos	2
# revestimento	1
# revestir	1
# revestirao	1
# revia	3
# reviradas	1
# reviralo	1
# revirando	1
# revirou	1
# revirouo	1
# revisitar	1
# revista	1
# revivendo	1
# reviver	3
# revivera	1
# reviveu	1
# revoada	1
# revoir	3
# revolta	8
# revoltado	2
# revoltados	1
# revolteando	1
# revolto	2
# revoltos	1
# revoltouse	1
# revolucionaria	1
# revolucionarias	2
# revolucionário	2
# revolucionários	1
# revolução	7
# revolvendo	2
# revolveuo	1
# revolvia	1
# revés	1
# revólver	1
# reza	3
# rezar	2
# rezarlhe	1
# rezas	1
# rezava	1
# rezes	1
# rezingão	1
# reúnem	1
# ri	3
# ria	24
# riam	4
# riase	2
# ribeiro	1
# ribombar	1
# rica	29
# ricamente	2
# ricas	8
# rico	42
# ricos	4
# rido	1
# ridícula	2
# ridículas	2
# ridículo	8
# ridículos	1
# riemse	1
# rien	1
# rifada	1
# right	4
# rigidez	3
# rigor	2
# rija	1
# rijo	3
# rijos	2
# rilhados	1
# rilhando	3
# rilhava	1
# rima	2
# rimas	4
# rimos	1
# rinche	1
# rindo	57
# rins	2
# rio	37
# rios	2
# ripanço	2
# riqueza	4
# riquezas	1
# rir	16
# rira	1
# riram	1
# ris	1
# risada	3
# risadas	7
# risadinha	2
# risca	3
# riscada	1
# riscadinho	1
# riscar	2
# riscas	2
# riscava	2
# risco	1
# rise	5
# risinhos	1
# riso	22
# risonha	7
# risonhamente	7
# risonho	27
# risos	9
# risota	1
# risse	1
# riste	1
# ritmo	3
# riu	13
# rivais	1
# rivalidade	1
# rixa	1
# riçado	1
# roastbeef	1
# robber	1
# robbers	1
# robe	2
# robedechambre	14
# roble	1
# robles	1
# robustez	3
# robusto	5
# robustíssimos	1
# rocha	4
# rochas	1
# rochedos	1
# rococó	1
# rococós	1
# roda	16
# rodando	2
# rodapé	1
# rodar	3
# rodas	16
# rodava	2
# rodeado	1
# rodeavam	1
# rodela	1
# rodelas	1
# rodo	1
# rodos	1
# rodou	6
# roendo	1
# roer	1
# rogalhe	1
# rogando	1
# rogou	1
# rojam	1
# rojavam	1
# rola	4
# rolalo	1
# rolando	6
# rolar	10
# rolara	4
# rolaremlhe	1
# rolava	6
# rolavam	4
# roldão	1
# rolem	1
# roleta	1
# rolha	2
# rolhas	1
# roliça	3
# roliças	1
# roliço	1
# rolo	5
# rolos	2
# rolou	10
# romagem	3
# romana	2
# romance	39
# romances	7
# romancesinho	1
# romancista	1
# romanesca	1
# romanesco	3
# romano	1
# romanos	2
# romanticamente	1
# romantismo	7
# romantismos	1
# romantizes	1
# romanza	1
# romanzeiras	1
# romaria	2
# romarias	1
# rompante	1
# rompe	1
# rompendo	4
# romper	2
# rompera	7
# romperam	3
# romperem	1
# rompesse	1
# rompeu	29
# rompeulhe	1
# rompia	4
# rompiam	1
# rompimento	3
# romântica	7
# românticas	3
# romântico	11
# românticos	4
# romã	1
# roncantes	1
# roncava	1
# ronceiro	2
# ronco	1
# rondando	3
# rondar	5
# rondava	3
# rondavam	2
# ronha	1
# ronronava	1
# roquesinho	1
# rosa	56
# rosada	3
# rosado	1
# rosados	2
# rosas	28
# roscas	1
# roseira	1
# roseiras	6
# roseou	1
# roseta	1
# rosetas	1
# rosinhas	1
# rosna	1
# rosnada	1
# rosnando	10
# rosnar	5
# rosnara	1
# rosnava	2
# rosnou	24
# rosnoulhe	1
# rosquinha	1
# rosse	1
# rosto	41
# rostos	2
# rostosinho	2
# rosário	1
# rota	1
# rotina	2
# rotineiras	1
# rotineiro	1
# roto	2
# rotunda	2
# rotundo	1
# roubada	1
# roubar	1
# roubo	1
# rouca	5
# rouco	6
# roucos	1
# roufenha	2
# roupa	23
# roupagens	3
# roupas	5
# roupão	6
# roupões	1
# rouquejou	1
# rouxinol	3
# rouxinóis	3
# roxas	2
# roxo	3
# roxos	2
# roçado	1
# roçando	3
# roçandolhe	1
# roçandose	3
# roçar	7
# roçara	1
# roçarem	1
# roçasse	1
# roçava	1
# roçavalhe	1
# roçavam	2
# roçou	1
# roíao	1
# roída	1
# roídas	2
# roídos	1
# rr	5
# rua	159
# ruas	20
# ruasita	1
# ruazinha	1
# rubis	2
# rubor	10
# ruborizavamse	1
# ruborzinho	1
# rubrica	1
# rubro	2
# rude	12
# rudes	1
# rudeza	2
# rufava	1
# ruga	3
# rugas	5
# rugeruge	2
# rugia	2
# rugidos	1
# rugindo	1
# rugir	1
# rugiu	6
# rugosas	1
# ruidosa	5
# ruidosamente	5
# ruidoso	3
# ruidosos	1
# ruins	2
# ruivas	3
# ruivo	1
# ruivos	3
# rum	1
# ruminando	2
# ruminante	1
# ruminar	1
# ruminara	1
# ruminava	2
# rumor	55
# rumores	4
# rumorosa	1
# rumorosas	1
# runing	1
# russa	2
# russo	1
# rutilante	2
# rutilantes	5
# ruído	11
# ruína	6
# ruínas	6
# rápida	1
# rápido	4
# rápidos	2
# rédea	2
# rédeas	2
# réis	17
# réplica	1
# réps	1
# rés	1
# réstia	2
# rês	2
# rígida	2
# rígidas	3
# rígido	9
# rígidos	2
# ríspido	1
# rôta	1
# rústica	1
# rústico	1
# s	18
# sa	2
# sabe	55
# sabedoria	1
# sabeis	1
# sabela	4
# sabelo	4
# sabem	12
# sabemos	1
# sabendo	6
# sabendoo	1
# saber	108
# saberem	3
# saberia	3
# saberá	1
# sabes	15
# sabese	2
# sabia	97
# sabiaa	1
# sabiam	11
# sabiamente	1
# sabiao	1
# sabias	2
# sabida	3
# sabonete	1
# sabor	8
# saboreando	1
# saboreava	1
# saboreou	1
# saborsinho	1
# sabre	3
# sabuja	1
# sabujice	2
# sabujices	1
# sabão	5
# sacada	1
# sacarei	1
# saciar	2
# saciara	1
# saciedade	3
# saco	4
# sacode	1
# sacola	1
# sacoroto	1
# sacou	2
# sacrifica	1
# sacrificar	2
# sacrificas	1
# sacrifico	1
# sacrifício	4
# sacrifícios	6
# sacristia	3
# sacrosanto	1
# sacrário	4
# sacré	1
# sacudia	7
# sacudialhe	1
# sacudiam	3
# sacudiao	1
# sacudida	1
# sacudidela	2
# sacudidos	2
# sacudindo	6
# sacudindoa	1
# sacudindolhas	1
# sacudir	7
# sacudirme	1
# sacudirmonos	1
# sacudiu	9
# sacudiuo	1
# sadios	1
# safada	1
# safar	1
# safarme	1
# safarse	1
# safarte	1
# safira	2
# safou	1
# sagas	1
# sagaz	2
# sagrada	6
# sagrado	3
# saguão	1
# saguões	1
# sai	5
# saia	25
# saialhe	1
# saiam	4
# saias	15
# saiba	4
# saindo	14
# saindolhe	1
# saio	1
# sair	41
# sairia	1
# sairse	1
# sairá	1
# sais	7
# saiu	36
# sal	2
# sala	200
# salame	1
# salas	18
# salero	2
# saleta	6
# salgado	1
# salientes	1
# salinha	2
# salmos	2
# saloia	1
# saloias	1
# saloios	2
# salpicada	1
# salpicado	4
# salpicandoo	1
# salpicar	1
# salta	5
# saltado	1
# saltando	5
# saltar	11
# saltara	2
# saltaram	1
# saltasse	2
# saltava	2
# salteador	1
# saltitando	1
# salto	8
# saltou	15
# salva	11
# salvadora	1
# salvam	1
# salvar	3
# salvas	1
# salvasse	2
# salvava	2
# salvação	2
# salvese	1
# salvou	1
# salão	26
# salões	3
# salõesdançantes	1
# sanctuário	1
# sandices	1
# sandwich	1
# sandwiches	3
# sanefas	4
# sangrentos	1
# sangrias	1
# sangue	57
# sanguíneo	1
# santa	13
# santas	1
# santidade	3
# santo	19
# santos	6
# santuário	3
# santuários	1
# santé	1
# sapatinho	1
# sapatinhos	1
# sapato	5
# sapatos	23
# sapatões	1
# sapos	1
# saque	3
# sarampo	1
# sarau	26
# sarcasmo	1
# sarcasmos	1
# sarcasticamente	1
# sarcástico	1
# sardenta	3
# sargeta	3
# sarja	3
# sarna	1
# sarrabulhada	1
# satisfactoriamente	1
# satisfazer	4
# satisfazia	2
# satisfação	10
# satisfações	1
# satisfeita	1
# satisfeitas	1
# satisfeito	5
# satisfez	1
# saturado	4
# satânico	2
# saudade	13
# saudades	9
# saudado	2
# saudando	3
# saudar	1
# saudavamse	1
# saudação	2
# saudosa	3
# saudosamente	1
# saudosas	1
# saudoso	3
# saudou	4
# saudála	1
# saudáveis	1
# saudável	2
# save	1
# saxonias	1
# saxónio	1
# saí	1
# saía	8
# saíam	2
# saída	4
# saídas	1
# saído	5
# saídos	1
# saímos	1
# saíra	12
# saíralhe	1
# saíram	2
# saírase	1
# saísse	3
# saíste	1
# saúde	25
# saúdes	1
# se	1436
# searas	1
# season	1
# sebe	2
# sebento	3
# sebes	1
# sebo	7
# sebácea	1
# sebáceo	1
# seca	15
# secado	2
# secamente	8
# secando	2
# secandolhe	1
# secarase	1
# secas	7
# secase	1
# seco	11
# secos	6
# secreta	6
# secretamente	1
# secretaria	4
# secretariasinha	4
# secretario	14
# secretarías	1
# secretas	1
# secreto	2
# secretos	1
# secretária	2
# secular	1
# seculares	2
# secura	3
# secção	1
# seda	69
# sedas	10
# sedativa	1
# sede	6
# seductor	1
# seduzia	1
# seduzido	3
# seduzira	1
# seduziu	1
# sedução	2
# seduções	1
# sege	4
# segredando	1
# segredar	1
# segredinhos	1
# segredo	28
# segredos	7
# segredou	2
# segue	1
# seguem	1
# seguia	14
# seguiam	4
# seguiamse	1
# seguiase	2
# seguida	5
# seguido	7
# seguidos	2
# seguilo	1
# seguindo	12
# seguindoa	1
# seguinte	36
# seguintes	1
# seguir	7
# seguira	2
# seguiram	3
# seguirem	1
# seguiriam	1
# seguirão	1
# seguisse	2
# seguiste	1
# seguiu	10
# seguiua	1
# seguiulhe	1
# seguiuos	1
# segunda	8
# segundafeira	5
# segundo	37
# segura	2
# segurando	2
# segurança	3
# segurar	1
# segurava	2
# seguro	9
# seguros	1
# sei	77
# seio	22
# seios	2
# seiosinho	2
# seis	32
# seiscentos	2
# seiva	1
# seixos	1
# seja	32
# sejam	2
# sejamos	1
# sejas	6
# sejes	1
# sela	2
# selado	1
# selar	1
# selo	2
# selva	1
# selvagem	6
# selvagens	4
# sem	402
# semana	22
# semanas	42
# semblante	3
# semeado	1
# semelhante	5
# semelhantes	2
# semelhanças	1
# seminuas	1
# seminudez	1
# sempiterna	1
# sempre	269
# senadores	1
# senda	1
# sendo	9
# senha	1
# senhas	1
# senhasinha	1
# senhor	102
# senhora	214
# senhoras	52
# senhores	33
# senhoril	1
# senhorio	2
# senil	1
# sensaboria	5
# sensaborões	1
# sensata	2
# sensatamente	1
# sensatas	2
# sensação	7
# sensações	1
# sensibilidades	1
# sensibilizado	2
# sensibilizouse	1
# senso	22
# sensual	2
# sensualidade	1
# sensível	1
# sentada	11
# sentado	23
# sentados	7
# sentandose	7
# sentar	11
# sentara	2
# sentaramse	2
# sentarase	9
# sentarse	15
# sentarselhes	1
# sentasse	1
# sentate	2
# sentavase	2
# sente	3
# sentemse	1
# sentes	1
# sentese	2
# sentia	48
# sentiaa	1
# sentialhes	1
# sentiam	2
# sentiao	2
# sentiase	12
# sentido	3
# sentilahia	1
# sentilo	1
# sentimentais	2
# sentimental	5
# sentimentalismo	1
# sentimentalmente	2
# sentimento	29
# sentimentos	5
# sentindo	24
# sentindoa	1
# sentindoo	1
# sentindose	3
# sentinela	3
# sentir	25
# sentira	8
# sentiram	4
# sentirem	1
# sentirlhes	1
# sentisse	3
# sentissem	1
# sentiu	23
# sentiuo	1
# sentiuse	2
# sentou	4
# sentouse	14
# senão	44
# separa	1
# separada	1
# separadas	2
# separado	4
# separados	4
# separam	1
# separar	4
# separara	1
# separarmos	1
# separarnos	1
# separarse	1
# separava	4
# separavam	2
# separavamse	1
# separação	10
# separei	1
# separouse	1
# sepulcro	1
# sepultado	1
# sepultarse	1
# sepultasse	1
# sepultis	2
# sepultoua	1
# sepultouse	1
# sepultura	3
# sepulturas	2
# sequer	17
# sequiosa	1
# sequioso	1
# ser	226
# sera	1
# serafim	1
# serem	4
# serena	6
# serenamente	4
# serenar	4
# serenata	1
# serenidade	6
# sereno	12
# serenou	1
# sereníssima	1
# seres	4
# serge	1
# seria	49
# seriam	2
# seriamente	5
# serias	1
# seriedade	4
# seriissima	1
# seringou	1
# seriosinho	1
# sermos	1
# sermões	2
# serpeavam	1
# serpentina	1
# serpentinas	7
# serra	8
# serradura	1
# serralho	5
# serranias	1
# sertão	1
# serve	5
# servem	1
# servente	3
# serves	1
# servia	8
# serviaa	1
# serviam	3
# service	1
# servida	1
# servidas	1
# servido	6
# servidos	2
# servindo	3
# servir	10
# servira	6
# serviram	2
# servirte	1
# servisse	1
# serviu	2
# serviçal	2
# serviço	13
# serviços	3
# servo	1
# será	3
# seráfica	1
# serão	7
# seríamos	1
# ses	1
# sessenta	4
# sesta	7
# sestas	2
# sete	17
# setembro	3
# seu	882
# seus	353
# severa	10
# severamente	2
# severas	3
# severidade	5
# severo	15
# severos	3
# sextafeira	1
# señorita	2
# shake	1
# shakehand	1
# shakehands	9
# shiling	2
# si	70
# sibilava	3
# sibilinas	1
# sicrano	1
# sido	29
# siga	1
# significa	3
# significando	2
# significativamente	1
# significava	2
# significação	3
# sigo	1
# silence	1
# silenciosa	16
# silenciosamente	4
# silenciosas	4
# silencioso	11
# silenciosos	1
# silvante	1
# silvar	1
# silvavam	1
# silvestre	3
# silvestres	2
# silvo	1
# silvos	1
# silêncio	150
# silêncios	8
# sim	46
# simbolizando	1
# simbolizasse	1
# simbólico	2
# simbólicos	1
# simetria	3
# similitude	2
# similitudes	1
# simpatia	14
# simpatias	2
# simpaticamente	1
# simpatizar	1
# simpatizara	1
# simples	55
# simplesmente	31
# simpleza	1
# simplicidade	9
# simplificava	2
# simplório	1
# simpática	3
# simpático	8
# simpáticos	1
# simulada	1
# simultânea	1
# sinais	3
# sinal	6
# sinalsinho	1
# sincera	2
# sinceramente	2
# sinceras	2
# sinceridade	6
# sincero	7
# sinceros	1
# sindicatos	3
# sineta	13
# sinete	4
# sinfonia	1
# singela	2
# singelas	1
# singular	3
# singularmente	1
# sinistra	3
# sino	1
# sinos	5
# sinta	2
# sinto	5
# sintoma	1
# sintomas	1
# sintome	1
# sintético	1
# sir	9
# sirigaita	1
# sirva	1
# sirvase	1
# sistema	6
# sistemas	1
# sisudez	2
# sisudo	1
# situada	1
# situação	4
# situações	1
# sleepingcar	1
# slécht	1
# so	2
# soa	1
# soalheira	1
# soalheiras	1
# soalheiro	1
# soalho	8
# soar	2
# soaram	2
# soava	1
# sob	158
# sobe	1
# sobelhe	1
# sobem	1
# soberanamente	1
# soberano	1
# soberanos	1
# soberba	8
# soberbamente	1
# soberbo	12
# soberbos	3
# sobrado	3
# sobrancelhas	5
# sobranceria	1
# sobrava	1
# sobravalhe	1
# sobraçava	1
# sobraçou	1
# sobre	467
# sobrecarregadas	1
# sobrecarregar	1
# sobrecasaca	44
# sobremesa	6
# sobrenatural	1
# sobrepostos	1
# sobrescritada	1
# sobrescritado	1
# sobrescrito	5
# sobrescritos	1
# sobressaltadas	1
# sobressalto	4
# sobressaltos	1
# sobressaíam	1
# sobretudo	43
# sobriamente	1
# sobrinha	2
# sobrinhita	2
# sobrinho	7
# sobrolho	2
# sociais	5
# social	17
# socialismo	1
# socialista	2
# sociedade	28
# sociedades	3
# sociedadesinha	1
# sociável	1
# soco	2
# socos	1
# soda	5
# soes	1
# soez	1
# sofra	1
# sofre	2
# sofregamente	4
# sofreguidão	4
# sofrendo	2
# sofrer	3
# sofrera	1
# sofreria	1
# sofri	2
# sofria	6
# sofriam	1
# sofriase	1
# sofridas	1
# sofrido	2
# sofrimento	3
# sofrimentos	2
# sofríamos	1
# sofá	86
# sofás	6
# sogra	1
# sogro	3
# soirée	18
# soirées	9
# sol	104
# sola	1
# solar	1
# solas	1
# solavancos	1
# soldado	3
# soldados	5
# sole	1
# solene	12
# solenemente	2
# solenes	5
# solenidade	13
# solenidades	1
# soleníssimo	1
# soletrar	1
# solicitara	1
# solicito	3
# solicitude	2
# solidamente	1
# solidariedade	2
# solidez	2
# solidário	1
# solidão	18
# solitariamente	7
# solitária	8
# solitárias	2
# solitário	6
# solitários	3
# solo	5
# solta	5
# soltado	1
# soltando	6
# soltar	3
# soltara	2
# soltas	3
# soltasse	1
# soltava	4
# soltei	2
# solteira	4
# solteiro	2
# solteirona	1
# solteirões	2
# solto	3
# soltos	6
# soltou	16
# soluçando	3
# soluçantes	1
# soluçar	1
# soluçava	3
# soluço	4
# soluços	11
# soluçou	1
# solução	5
# solva	1
# solzinho	1
# som	15
# soma	7
# somado	1
# sombra	53
# sombras	9
# sombria	9
# sombriamente	4
# sombrias	1
# sombrinha	3
# sombrinhas	3
# sombrio	23
# sombrios	2
# somem	1
# somente	8
# somos	10
# son	3
# sondava	1
# sondeia	1
# soneto	5
# sonetos	1
# sonha	1
# sonhara	2
# sonhei	1
# sonhem	1
# sonho	11
# sonhos	9
# sonhou	2
# sono	6
# sonolenta	1
# sonolento	1
# sonolência	3
# sonora	1
# sonoras	1
# sonoridade	3
# sonoridades	1
# sonoro	3
# sonoros	1
# sonos	1
# sons	3
# sonâmbulo	4
# sopa	8
# sopas	5
# soprando	3
# soprandolhe	1
# soprar	1
# soprava	2
# sopro	11
# soprou	1
# sordidamente	1
# sordidez	4
# sorrateira	1
# sorri	2
# sorria	45
# sorrialhe	1
# sorrialhes	1
# sorriam	7
# sorrindo	71
# sorrindolhe	1
# sorrindolhes	1
# sorrio	4
# sorrir	15
# sorriram	2
# sorriramse	1
# sorrisinho	1
# sorriso	68
# sorrisos	6
# sorriu	21
# sorte	20
# sorumbática	1
# sorumbáticas	1
# sorumbáticos	1
# sorver	1
# sorverlhe	1
# sorveu	1
# sorvia	1
# sorvido	1
# sorvo	4
# sossega	1
# sossegada	2
# sossegadamente	3
# sossegado	2
# sossegando	1
# sossegar	2
# sossegava	2
# sossego	10
# sossegou	2
# sotaque	3
# soturna	2
# soturnamente	1
# sou	30
# soube	20
# souber	1
# soubera	6
# souberamse	1
# soubesse	11
# soubessem	1
# soubesses	2
# soubeste	1
# sous	2
# sova	4
# sovada	1
# sovado	1
# sozinha	2
# sozinho	1
# speech	2
# spleen	5
# sport	10
# sportman	8
# sportmen	1
# sports	2
# srs	2
# stacato	1
# star	2
# starter	3
# stores	4
# stá	1
# sua	765
# suada	1
# suando	2
# suas	166
# suave	16
# suavemente	3
# suaves	5
# suavidade	5
# subalternas	1
# subalternos	1
# subentendia	1
# subia	9
# subiam	2
# subida	2
# subido	1
# subindo	9
# subir	19
# subira	5
# subiram	3
# subirem	2
# subirlhe	1
# subissem	1
# subitamente	16
# subiu	26
# subiulhe	2
# sublime	19
# sublimemente	2
# sublimes	2
# sublinhando	2
# sublinhara	1
# submissa	1
# submisso	2
# submissão	1
# subscrição	1
# subsidio	1
# substituese	1
# substituila	1
# substituir	2
# substituído	1
# substituísse	1
# substância	2
# subterrâneo	1
# subtil	7
# subtilezas	1
# subtilmente	4
# subtis	4
# subúrbio	2
# subúrbios	1
# suceda	1
# sucede	4
# sucedem	1
# sucedendo	1
# suceder	5
# sucedera	1
# sucedeu	4
# sucedeulhe	2
# sucedia	1
# sucedido	2
# sucessivamente	2
# sucessivas	3
# sucesso	2
# sucessos	1
# sucumbiam	1
# sucumbida	3
# sucumbido	4
# sucumbidos	1
# sucumbindo	1
# sucumbir	1
# sucumbiu	1
# sudoeste	7
# sudário	1
# sudários	1
# sueco	1
# suficiente	2
# suficientemente	1
# sufocada	6
# sufocadas	1
# sufocado	12
# sufocados	3
# sufocando	1
# sufocandose	1
# sufocante	1
# sufocar	3
# sufocara	1
# sufocaram	1
# sufocassem	1
# sufocava	7
# sufocavam	1
# sufocouo	1
# sugandoa	1
# sugeria	1
# sugerido	1
# sugeridos	1
# sugeriraa	1
# sugeriu	3
# suicídio	1
# suis	7
# suissas	9
# suja	8
# sujando	2
# sujas	3
# sujasteme	1
# sujeito	30
# sujeitos	20
# sujo	8
# sujos	1
# sujou	1
# sul	2
# sulcarao	1
# sulcavam	1
# sulco	3
# sulcos	3
# suma	2
# sumamente	1
# sumaria	1
# sumariamente	1
# sumiase	1
# sumiaselhe	1
# sumida	2
# sumido	4
# sumidos	3
# sumindo	1
# sumiram	1
# sumiramse	1
# sumirase	1
# sumirse	2
# sumiuse	1
# sumiço	1
# sumo	1
# sumptuosa	2
# sumptuoso	2
# suor	10
# superficiais	1
# superficial	1
# superfície	3
# superior	22
# superiores	6
# superioridade	10
# superiormente	2
# supersticioso	1
# suplica	3
# suplicando	1
# suplicante	3
# suplicantes	1
# suplicas	3
# suplicava	1
# suplicação	2
# suplicou	1
# suplício	1
# supondo	1
# supondoa	2
# suponho	2
# supor	3
# suporta	1
# suportar	2
# suposição	2
# supracómico	1
# suprema	7
# supremamente	1
# supremo	10
# suprimi	1
# suprimida	1
# suprimido	1
# suprimir	1
# suprir	1
# supunha	5
# supõe	2
# supõem	2
# surda	2
# surdamente	5
# surdas	1
# surdia	1
# surdir	1
# surdiu	2
# surdo	10
# surdos	2
# surge	1
# surgia	2
# surgiam	4
# surgindo	4
# surgir	2
# surgira	3
# surgiramlhe	1
# surgisse	2
# surgiu	12
# surpreende	1
# surpreendendo	1
# surpreender	1
# surpreendera	2
# surpreendeu	2
# surpreendeua	1
# surpreendia	1
# surpreendida	4
# surpreendido	12
# surpreendidos	1
# surpresa	37
# surpresas	1
# surripiado	1
# surripiaralhe	1
# surripiarlhe	1
# sursum	1
# surtiu	1
# susceptíveis	1
# suspeita	5
# suspeitando	1
# suspeitas	4
# suspeitasse	1
# suspeitava	3
# suspeito	2
# suspendendo	1
# suspendeu	1
# suspendeuse	1
# suspensa	4
# suspensas	1
# suspenso	3
# suspensos	4
# suspensão	1
# suspensórios	1
# suspirando	3
# suspirar	1
# suspirava	2
# suspirinho	1
# suspiro	37
# suspiros	4
# suspirosinho	1
# suspirou	5
# sussurrara	1
# sussurrava	1
# sussurração	1
# sussurro	5
# sustara	1
# sustendo	1
# sustentando	2
# sustentar	4
# sustentava	1
# sustentou	1
# suster	1
# susto	5
# sustos	1
# sustêm	1
# susurração	2
# sábado	12
# sábia	1
# sábio	2
# sândalo	1
# são	85
# sãome	1
# século	30
# séculos	4
# séria	34
# sérias	8
# série	2
# sério	52
# sérios	12
# sétimo	1
# sétourdir	1
# sê	3
# sífilis	1
# sílabas	2
# símbolo	1
# símbolos	1
# síntese	1
# sínteses	1
# sítio	7
# sítios	5
# só	302
# sóbrio	5
# sócio	1
# sócios	1
# sólida	7
# sólido	5
# sórdido	6
# sós	15
# sótão	3
# sô	8
# sôfrega	2
# sôfrego	4
# sôfregos	1
# súbita	2
# súbitas	1
# súbito	2
# súcia	3
# ta	2
# tabacaria	1
# tabaco	7
# tabela	2
# tabelião	2
# taberna	3
# tabernas	1
# taberneiro	1
# tabernáculo	3
# tabique	3
# tabiques	1
# tablado	6
# tabuado	4
# tabuleiro	3
# tabuleiros	1
# tabuleta	2
# taciturno	4
# taciturnos	1
# taco	7
# tacteava	1
# tacto	2
# tacão	3
# tacões	3
# tafetá	1
# tagarelado	1
# tagarelar	2
# tagarelice	6
# tais	5
# tal	38
# talagarça	5
# talento	31
# talentos	3
# talentosa	1
# talentoso	1
# talha	2
# talhada	2
# talhadas	1
# talhado	2
# talhavase	1
# talher	12
# talheres	1
# talim	1
# talvez	89
# tamanho	1
# tambor	2
# tambores	1
# também	319
# tampa	3
# tanga	2
# tangendo	1
# tanglewood	1
# tangível	2
# tank	1
# tanque	4
# tanques	1
# tanquesinho	1
# tanta	24
# tantas	21
# tanto	50
# tantos	13
# tantum	1
# tapado	1
# tapando	3
# tapeias	1
# tapetada	3
# tapetado	1
# tapete	44
# tapetes	5
# tapeçaria	5
# tapeçarias	14
# tapioca	1
# tapona	3
# tapoulhe	1
# tapume	1
# taramelava	1
# tarantantan	1
# tarantela	1
# tarda	1
# tardar	1
# tardaram	2
# tardaria	2
# tarde	136
# tardes	11
# tardia	1
# tardinha	1
# tardo	2
# tardou	7
# tarefa	2
# tareia	1
# tarifada	1
# tarimbeiro	2
# tarjado	1
# tartamudear	1
# tartamudeou	1
# tartaruga	1
# tartarugas	1
# tas	1
# taverna	2
# tavernas	1
# taxas	1
# taça	2
# taças	1
# taçasinha	1
# te	146
# teatrais	1
# teatral	2
# teatreco	1
# teatro	15
# teatros	3
# teciam	1
# tecido	1
# teclado	7
# teclas	1
# tecto	16
# tectos	4
# teia	1
# teias	2
# teima	5
# teimava	1
# teimoso	4
# teimou	2
# tela	10
# telahia	1
# telegrafar	2
# telegrafo	2
# telegrama	13
# telegramas	7
# telhado	5
# telhados	1
# telhas	3
# telhudo	2
# telo	3
# telégrafos	1
# tem	181
# temas	1
# temela	1
# temendo	2
# temerariamente	1
# temerosa	1
# temeroso	1
# temia	2
# temido	2
# temlhe	3
# temlo	1
# temme	2
# temno	1
# temolo	3
# temos	34
# tempera	2
# temperamento	7
# templo	3
# tempo	145
# temporal	2
# tempos	40
# temse	3
# tenacidade	1
# tenazes	1
# tencionas	1
# tencionava	3
# tencionavam	3
# tenciono	1
# tenda	3
# tendas	2
# tendeiro	1
# tender	1
# tendo	46
# tendoa	2
# tendolhe	1
# tendose	1
# tendência	2
# tendências	1
# tenebrosa	4
# tenebroso	2
# tenha	12
# tenhamos	1
# tenhas	4
# tenho	85
# tenor	2
# tenores	2
# tenra	2
# tenras	2
# tenro	2
# tenros	1
# tens	56
# tenta	1
# tentado	1
# tentadoramente	1
# tentam	1
# tentandoo	1
# tentar	2
# tentara	2
# tentas	1
# tentativa	1
# tentava	8
# tentavam	1
# tentavamno	1
# tentação	7
# tenteando	2
# tenteava	1
# tentou	2
# tenuidade	1
# tenção	1
# teologia	1
# teológico	1
# teoria	7
# teorias	1
# tepidamente	1
# ter	189
# terceira	1
# terceiro	4
# terceto	1
# terebentina	1
# terem	5
# teres	2
# teria	26
# teriam	2
# terlhe	2
# termina	1
# terminada	2
# terminam	1
# terminando	1
# terminante	1
# terminar	2
# terminara	3
# terminaram	1
# terminassem	1
# terminava	7
# terminou	30
# termo	2
# termos	8
# termómetro	1
# terna	3
# ternamente	5
# ternas	1
# terno	10
# ternos	1
# ternura	19
# ternuras	2
# terra	43
# terras	7
# terraço	43
# terraços	1
# terreiro	4
# terreno	3
# terrenos	2
# terres	1
# terrestre	1
# terrina	1
# terriola	1
# território	1
# terrivelmente	5
# terror	21
# terrores	2
# terríveis	6
# terrível	23
# terse	1
# terás	1
# terça	2
# terçafeira	4
# terças	2
# terçasfeiras	4
# terço	3
# teríamos	1
# tesa	1
# teso	5
# tesos	2
# tesoura	1
# tesoureiro	1
# tesouros	1
# testa	33
# testada	1
# testamentária	1
# testasinha	1
# testemunha	3
# testemunhar	3
# testemunhas	3
# testemunho	1
# teu	39
# teus	4
# teve	102
# textuais	1
# textualmente	1
# teólogo	1
# that	1
# ti	27
# tia	14
# tiara	1
# tido	5
# tigela	1
# tigre	3
# tijolo	3
# tilintar	2
# tilintaram	1
# tilintir	1
# timbre	3
# timidamente	5
# timidez	3
# tina	2
# tinha	385
# tinhaa	2
# tinhaas	1
# tinhalhe	7
# tinhalho	3
# tinham	150
# tinhame	1
# tinhamlhe	2
# tinhamna	1
# tinhamno	3
# tinhamse	14
# tinhao	3
# tinhas	7
# tinhase	2
# tinhaslhe	1
# tinhate	2
# tinia	1
# tinir	3
# tinta	7
# tintas	1
# tiníamos	1
# tio	36
# tios	1
# tipa	2
# tipo	18
# tipos	3
# tiposinho	2
# tipóia	56
# tipóias	3
# tira	9
# tirabotas	1
# tiracolo	7
# tirado	2
# tirados	1
# tiragem	5
# tiram	1
# tirando	19
# tiranos	1
# tirante	1
# tirar	18
# tirara	5
# tirarlhe	1
# tirasse	3
# tirava	7
# tiravam	4
# tire	3
# tiritando	1
# tiritar	2
# tiro	3
# tirolesa	1
# tiros	2
# tirou	10
# tiroulhe	2
# tisnada	1
# tisnadas	1
# tisnado	1
# titi	22
# titular	1
# tive	16
# tivemolas	1
# tivemos	3
# tiver	1
# tivera	27
# tiveraa	1
# tiveram	3
# tiverem	1
# tivesse	44
# tivessem	1
# tiveste	2
# tivéssemos	1
# to	2
# toada	2
# toaletes	1
# toalha	11
# toalhas	1
# toca	8
# tocadas	1
# tocado	4
# tocados	1
# tocando	10
# tocandolhe	1
# tocante	4
# tocar	7
# tocara	1
# tocaralhe	1
# tocarao	1
# tocarem	1
# tocarlhe	1
# tocará	1
# tocasse	1
# tocassem	2
# tocava	13
# tocavalhe	1
# tocavam	2
# tocavase	1
# tocha	1
# tocou	9
# tocoulhe	6
# toda	268
# todas	115
# todavia	23
# todo	295
# todos	165
# toilete	20
# toiletes	6
# toiro	2
# toiros	1
# tola	1
# toldado	1
# toldo	5
# toldos	1
# tolera	2
# tolerando	1
# tolerar	1
# tolerava	3
# tolero	3
# tolerável	1
# tolhesse	1
# tolice	16
# tolices	1
# tolo	1
# tolos	1
# tom	64
# toma	2
# tomada	5
# tomado	14
# tomados	1
# tomalas	1
# tomalo	1
# tomame	1
# tomando	14
# tomandolhe	2
# tomar	33
# tomara	11
# tomaralhe	1
# tomaram	1
# tomarase	1
# tomaria	1
# tomarlhe	2
# tomas	2
# tomase	1
# tomate	2
# tomates	1
# tomava	18
# tomavalhe	1
# tomavam	6
# tomavamno	1
# tombadas	1
# tombado	2
# tombava	1
# tombou	2
# tome	3
# tomei	1
# tomem	1
# tomo	1
# tomou	24
# tomoulhe	8
# tonificação	1
# tons	27
# tonta	5
# tontas	2
# tonteira	1
# tonteria	1
# tonto	3
# tontura	1
# tonturas	2
# topada	1
# topete	2
# topo	4
# topou	2
# toque	4
# toques	1
# torcendo	5
# torceu	1
# torcia	4
# torciase	1
# tormenta	1
# tormento	6
# tormentos	2
# tormentosa	1
# torna	3
# tornadas	1
# tornado	1
# tornam	1
# tornamos	1
# tornamse	1
# tornando	10
# tornandoo	1
# tornandose	2
# tornar	13
# tornara	12
# tornaram	1
# tornaramse	1
# tornarao	1
# tornarase	8
# tornaria	3
# tornarse	2
# tornarsehia	1
# tornase	2
# tornasse	3
# tornava	10
# tornavalha	1
# tornavam	2
# tornavao	1
# tornavase	5
# torne	1
# torneada	1
# torneados	1
# tornei	3
# torneio	1
# torneios	1
# torneira	1
# torno	31
# tornou	15
# tornoulhe	1
# tornouse	3
# tornámos	1
# torpe	12
# torpedos	1
# torpemente	1
# torpes	2
# torpeza	3
# torpezas	2
# torpor	1
# torrar	2
# torrava	1
# torre	5
# torrencial	1
# torres	1
# torrãosinho	1
# torrões	1
# tort	1
# tortulho	1
# tortuosa	1
# tortura	4
# torturado	3
# torturala	1
# torturando	1
# torturandose	1
# torturante	1
# torturar	1
# torturas	1
# torturasse	1
# torturava	3
# torturavam	2
# torturoume	1
# torvelinho	1
# tory	1
# tosca	4
# toscas	1
# tosco	1
# toscos	1
# tosse	7
# tosses	1
# tossia	2
# tossiam	1
# tossir	2
# tossira	2
# tossiu	4
# tostons	1
# tostão	3
# tostões	14
# tostõesinhos	2
# total	1
# totalmente	1
# touca	4
# toucador	13
# toujours	3
# tourada	9
# toureiro	1
# touriste	2
# touristes	1
# touro	9
# touros	6
# tout	1
# toute	2
# trabalha	1
# trabalhada	2
# trabalhadas	1
# trabalhado	3
# trabalhador	2
# trabalhadores	1
# trabalhados	1
# trabalhamos	1
# trabalhar	5
# trabalhara	1
# trabalhas	1
# trabalhase	1
# trabalhasse	1
# trabalho	36
# trabalhos	6
# tradicional	1
# tradicionalmente	1
# tradição	3
# tradições	4
# traduzida	1
# traduzido	1
# traduzidos	1
# traduzir	1
# traduções	2
# traga	2
# tragame	1
# tragamno	1
# tragar	1
# tragicamente	3
# trago	8
# tragoa	1
# tragos	1
# tragou	1
# tragédia	4
# traia	2
# traidor	2
# traiçoeira	1
# traição	3
# traje	3
# trama	3
# tramada	1
# trambolho	2
# trambolhões	2
# tramóia	1
# trancas	1
# tranquila	6
# tranquilamente	19
# tranquilidade	7
# tranquilizar	3
# tranquilizasse	1
# tranquilizou	2
# tranquilizoua	1
# tranquilizouo	2
# tranquilo	12
# tranquilos	2
# transacção	2
# transbordando	4
# transbordar	2
# transbordava	4
# transbordou	1
# transcrições	1
# transe	1
# transformar	4
# transformara	1
# transformarse	1
# transformavase	1
# transformação	2
# transformações	1
# transia	1
# transido	2
# transição	3
# transluziam	1
# transmitir	1
# transmitiu	1
# transmontano	2
# transparecendo	1
# transpareceu	1
# transparecia	4
# transparente	5
# transparentes	4
# transparência	2
# transparências	1
# transpirar	1
# transportado	1
# transportando	1
# transportar	1
# transpunha	1
# transtornada	3
# transtornado	2
# transviada	1
# transviados	1
# trança	2
# tranças	7
# trapalhada	1
# trapalhadas	1
# trapalhão	2
# trapeira	2
# trapista	1
# trapo	3
# trapos	2
# trapésio	4
# trapézio	8
# traquitana	6
# trarei	1
# traria	3
# trasladado	1
# trasladar	1
# traste	4
# trata	12
# tratada	1
# tratado	3
# tratados	1
# tratalo	1
# tratamento	2
# tratamse	2
# tratando	4
# tratandoo	1
# tratandose	1
# tratar	9
# trataramse	1
# tratarme	1
# tratarse	1
# tratase	2
# tratasse	2
# tratava	9
# tratavaa	1
# tratavam	2
# tratavamse	3
# tratavao	1
# tratavase	1
# tratou	1
# tratássemos	1
# trauteando	1
# travadas	1
# travando	6
# travandolhe	1
# travaralhe	1
# travavase	1
# travers	1
# traves	1
# travessa	13
# travessas	1
# travesseiro	7
# travesseiros	3
# travessia	1
# travessias	1
# travou	5
# traz	49
# trazeme	1
# trazendo	12
# trazendoa	1
# trazendolhe	1
# trazer	15
# trazerlhe	2
# trazes	1
# trazia	47
# trazialhe	3
# traziam	5
# traziao	1
# trazias	1
# trazidas	1
# trazido	5
# traça	1
# traçada	4
# traçando	1
# traçar	4
# traçava	2
# traço	6
# traído	3
# trecho	2
# trem	6
# tremedal	1
# tremelicando	1
# tremenda	4
# tremendas	3
# tremendo	11
# tremer	20
# tremerlhe	1
# tremeu	1
# tremia	20
# tremiam	4
# tremiamlhe	1
# tremo	1
# tremor	2
# tremoço	1
# tremula	10
# tremulas	3
# tremulo	16
# tremura	1
# tremó	3
# trens	3
# trenó	1
# trepadeira	2
# trepadeiras	4
# trepado	1
# trepando	1
# trepar	3
# treparam	1
# trepava	3
# tresnoitada	1
# trespassados	1
# trespassalo	1
# trespassandose	2
# trespassar	1
# trespassasse	1
# trespassava	1
# treva	8
# trevas	3
# treze	1
# trezentas	1
# trezentos	2
# tribuna	35
# tribunais	1
# tribunal	2
# tribunas	2
# tricorne	2
# trigo	1
# trigueira	1
# trigueiras	1
# trigueiro	7
# trigueirota	1
# trigueirotas	1
# trilhar	1
# trincando	4
# trinchava	1
# trinta	8
# trintanário	9
# triplicado	1
# triste	67
# tristemente	7
# tristes	15
# tristeza	22
# tristezas	2
# tristinha	1
# tristonha	4
# tristonho	8
# tristonhos	2
# triturando	1
# triumvirato	1
# triunfador	1
# triunfal	1
# triunfando	1
# triunfante	12
# triunfantemente	1
# triunfar	1
# triunfara	1
# triunfava	6
# triunfo	11
# triunfou	1
# trivial	2
# trivialidade	1
# troca	1
# trocada	2
# trocadas	1
# trocado	3
# trocando	1
# trocar	1
# trocara	1
# trocaram	4
# trocava	1
# trocista	1
# troco	7
# troféu	1
# troféus	1
# trombuda	1
# trombudo	3
# troncos	1
# trono	2
# tropa	2
# tropel	4
# tropeçando	5
# tropeçara	2
# tropeçou	3
# tropeções	1
# tropical	1
# trota	1
# trotando	4
# trotava	3
# trote	13
# trotoir	1
# trotou	1
# trouvait	1
# trouvée	1
# trouxa	2
# trouxasinha	3
# trouxe	11
# trouxea	1
# trouxelhe	1
# trouxeme	3
# trouxeo	2
# trouxera	14
# trouxeraa	1
# trouxerao	1
# trouxesse	2
# trouxete	1
# trovejou	4
# trovoada	1
# trovão	1
# troça	7
# troçado	1
# troças	1
# troço	1
# truc	4
# trufa	1
# trágica	3
# trágico	1
# trás	5
# très	19
# trèschic	2
# trégua	1
# trémulos	5
# três	119
# trôpego	1
# tu	206
# tua	35
# tuas	7
# tubos	1
# tudo	328
# tufados	1
# tufavam	1
# tugiu	1
# tugúrio	1
# tules	1
# tulipa	2
# tulipas	2
# tumido	2
# tumidos	1
# tumular	1
# tumulto	11
# tumultuosa	7
# tumultuosamente	2
# tumultuosas	2
# tumultuoso	3
# turba	2
# turbar	1
# turbilhão	1
# turbulenta	1
# turco	2
# turcos	2
# turno	1
# turva	1
# turvo	2
# turvos	3
# tutelar	2
# tábua	3
# tácita	1
# táctica	2
# tãbem	1
# tão	355
# técnicos	1
# tédio	15
# tédios	1
# ténue	4
# tépida	7
# tépido	5
# térrea	1
# térreos	2
# têm	24
# têrivêl	1
# tímida	7
# tímidas	1
# tímido	9
# tímidos	2
# tínhamos	4
# típico	1
# tísico	3
# título	8
# títulos	4
# tóca	1
# túmulo	1
# túnica	1
# ufanava	1
# uivar	1
# uivava	1
# uivos	2
# ulster	5
# ultima	17
# ultimamente	16
# ultimas	10
# ultimo	20
# ultrages	1
# ultrajado	1
# ultrajante	2
# ultraje	2
# um	3026
# uma	2170
# umas	43
# umbigo	1
# umbrais	1
# un	7
# una	2
# une	5
# ungido	1
# unhas	5
# unia	1
# uniamse	1
# unicamente	5
# unida	1
# unidas	1
# unido	1
# unidos	1
# uniforme	1
# uniformes	1
# uniramse	2
# universal	1
# universo	4
# união	6
# uniões	1
# uns	47
# unânime	1
# upa	1
# urgente	5
# urgentemente	2
# urgência	1
# urro	1
# urros	3
# urso	7
# usa	2
# usado	1
# usados	1
# usando	1
# usandolhe	1
# usao	1
# usar	5
# usarem	1
# usasse	1
# usava	5
# usei	1
# uso	3
# usouo	1
# usted	2
# ustêd	2
# usual	1
# utilizar	1
# utilizo	1
# uvas	3
# v	1
# va	2
# vaca	1
# vacas	2
# vacilando	1
# vacilar	1
# vacilações	1
# vadiagem	2
# vadiando	1
# vadiar	1
# vadiava	1
# vadio	1
# vadios	3
# vaga	16
# vagamente	18
# vagar	18
# vagares	6
# vagarosa	1
# vagarosamente	7
# vagaroso	4
# vagas	3
# vago	41
# vagos	5
# vagueando	2
# vai	59
# vaidade	2
# vaidosas	1
# vaidoso	1
# vailhe	2
# vailhes	1
# vais	16
# vaise	7
# vaite	2
# vale	18
# valem	2
# valendo	1
# valente	4
# valentes	1
# valentão	1
# valer	15
# valeria	1
# valerse	1
# vales	5
# valete	2
# valeu	1
# valho	1
# valia	4
# valiam	1
# validado	1
# valor	6
# valoroso	1
# valsa	7
# valsando	1
# valsar	1
# valsas	2
# vamonos	3
# vamos	25
# vantagem	4
# vantagens	1
# vapor	3
# vaporoso	1
# vara	2
# varado	2
# varanda	10
# varandas	6
# varandinha	1
# varandoo	1
# varapau	2
# varar	2
# varias	3
# variedade	1
# variedades	1
# varina	1
# varinas	1
# varinos	1
# varou	1
# varrendo	1
# varrer	3
# varreu	1
# varriam	1
# varriase	1
# varão	5
# varões	2
# vasa	2
# vasando	1
# vaso	8
# vasos	12
# vasta	19
# vastas	3
# vastidão	3
# vasto	17
# vastos	3
# vatil	2
# vaya	1
# vazia	6
# vazias	10
# vazio	3
# vazios	2
# vedes	1
# veemente	1
# veementes	2
# veemência	2
# vegetais	1
# veia	9
# veias	5
# veio	98
# veiolhe	8
# veiolhes	1
# veiome	4
# veja	9
# vejam	2
# vejo	5
# vejome	1
# vejoo	1
# vela	12
# velada	1
# veladas	1
# velado	1
# velador	1
# velar	1
# velas	21
# velavaa	1
# velavase	1
# velha	76
# velhaco	6
# velhas	14
# velhice	14
# velhinho	1
# velho	195
# velhos	25
# veludilho	3
# veludo	57
# veludos	7
# vem	45
# vemos	2
# vemse	1
# vence	1
# vencendo	1
# vencer	2
# vencera	1
# vencia	2
# vencida	3
# vencido	3
# vencidos	2
# venda	4
# vendas	1
# vendavais	2
# vendaval	6
# vende	2
# vender	6
# venderam	1
# venderase	1
# venderlhe	1
# vendia	2
# vendo	44
# vendoa	4
# vendoo	6
# veneno	2
# venerado	1
# venerando	1
# venerar	1
# veneração	9
# venerável	6
# venezianas	1
# venha	13
# venham	2
# venhas	6
# venho	10
# venhome	1
# vens	10
# venta	1
# ventas	1
# vento	27
# ventos	1
# ventre	8
# ventresinho	1
# ventura	2
# venu	2
# ver	188
# veras	1
# verbena	10
# verbo	2
# verbos	2
# verbosidade	1
# verdade	113
# verdadeira	7
# verdadeiramente	8
# verdadeiras	1
# verdadeiro	13
# verdadeiros	3
# verdades	2
# verdadesinhas	1
# verde	44
# verdeclaros	1
# verdeescura	2
# verdeescuro	1
# verdeescuros	1
# verdegarrafa	1
# verdejando	2
# verdejava	3
# verdenegra	1
# verdenegro	2
# verdes	10
# verdura	3
# verduras	5
# vereador	1
# vereda	2
# verei	2
# verem	2
# veremos	2
# vergando	1
# vergastadas	3
# vergastando	1
# vergastar	1
# vergastas	1
# vergava	1
# vergavam	1
# vergavamse	1
# vergonha	21
# vergou	1
# vergões	1
# veria	9
# veriam	1
# verificando	1
# verificar	3
# verificou	4
# verlhe	3
# verlhes	1
# vermelha	18
# vermelhas	6
# vermelhejando	1
# vermelhejava	1
# vermelhejavamlhe	1
# vermelhidão	2
# vermelho	40
# vermelhos	8
# vermelhão	1
# vermina	3
# vermos	1
# vermute	4
# verniz	22
# vernizes	1
# verosimilhança	2
# verosímil	1
# vers	1
# versalhada	3
# verse	2
# verselhe	1
# versinhos	1
# verso	7
# versos	15
# versículos	2
# verte	2
# verticais	1
# vertigem	1
# vertigens	1
# verve	8
# very	1
# verá	1
# verás	2
# verão	45
# verídico	1
# vesgos	1
# veste	1
# vestete	2
# vestia	5
# vestiam	1
# vestiase	2
# vestida	23
# vestidas	2
# vestido	53
# vestidos	19
# vestimenta	1
# vestindo	3
# vestir	11
# vestira	1
# vestiram	1
# vestirnos	1
# vestirse	3
# vestiu	1
# veston	2
# vestuário	1
# vestígio	1
# vestígios	3
# veterano	2
# veux	2
# vexada	2
# vexado	2
# vexame	1
# vez	172
# vezes	133
# vi	13
# via	56
# viaa	5
# viagem	29
# viagens	10
# viajado	1
# viajam	1
# viajando	2
# viajantes	2
# viajar	4
# viajara	3
# viajou	1
# vialhe	1
# viam	4
# viame	1
# viamna	1
# viao	2
# vias	1
# viase	4
# viação	1
# vibrando	2
# vibrante	4
# vibrar	4
# vibrava	1
# vibravam	1
# vibração	4
# vibrou	4
# vicecônsul	1
# vicejante	1
# viciosas	1
# viciosos	1
# vida	151
# vide	1
# vidinha	1
# vidrado	2
# vidraça	8
# vidraças	10
# vidrilhos	2
# vidro	11
# vidros	15
# vie	1
# viela	3
# vielas	2
# viendrait	1
# vienenses	1
# vier	3
# viera	50
# vieram	8
# vieramlhe	1
# viesse	15
# viessem	2
# viesses	1
# vieste	2
# vieux	1
# vigas	1
# vigiar	3
# vigiava	1
# vigilante	1
# vigor	1
# vigorosamente	1
# vigília	2
# vil	6
# vila	11
# vilas	2
# vilipendiar	1
# vilão	3
# vim	8
# vime	1
# vimonos	1
# vimos	4
# vincada	1
# vincos	1
# vinda	5
# vindo	21
# vindolhe	1
# vingado	2
# vingança	6
# vingar	2
# vingarse	1
# vingou	1
# vinha	100
# vinhalhe	1
# vinham	7
# vinhamse	1
# vinhase	2
# vinhaça	1
# vinhedos	1
# vinho	16
# vinhos	9
# vinte	15
# vintista	1
# vinténs	1
# vio	1
# viola	2
# violenta	1
# violentamente	12
# violentas	3
# violento	6
# violeta	3
# violetas	3
# violoncelos	1
# violência	6
# vir	73
# vira	50
# viraa	5
# viraas	1
# viragos	1
# viram	3
# virando	1
# virandoa	1
# virandose	1
# virao	3
# virase	1
# virem	2
# vires	1
# virgem	4
# virgens	1
# virginais	1
# virginal	5
# viria	6
# viril	4
# virilmente	1
# virou	4
# virrsconde	3
# virtude	5
# virtudes	1
# virtuosa	2
# virtuosas	1
# virtuoso	1
# virá	2
# virão	1
# visco	1
# visconde	13
# viscondessa	19
# viscosa	1
# viseira	2
# visinho	2
# visita	29
# visitado	1
# visitalos	1
# visitar	11
# visitarao	3
# visitas	6
# visitasse	1
# visitava	4
# visse	6
# vissem	1
# vista	22
# vistas	3
# viste	7
# visto	30
# vistoria	1
# vistosamente	1
# vistoso	2
# vistosos	1
# visão	4
# visíveis	1
# visível	2
# vite	1
# vitrine	1
# vitrines	1
# vitória	13
# viu	39
# viua	3
# viume	1
# viuos	1
# viuse	1
# viva	22
# vivacidade	2
# vivam	1
# vivamente	20
# vivas	9
# vivazes	1
# vive	17
# vivem	3
# vivemos	4
# vivenda	9
# vivendas	1
# vivendasinha	1
# vivendo	5
# viver	32
# vivera	5
# viveriam	1
# viveríamos	1
# vivesse	1
# viveu	3
# vivi	1
# vivia	26
# viviam	5
# vivido	2
# vivo	28
# vivos	8
# vizinha	5
# vizinhança	7
# vizinho	5
# viçosa	1
# viçosas	1
# viúva	10
# viúvo	9
# voa	1
# voam	2
# voando	2
# voar	4
# voara	1
# voasse	3
# voava	1
# voavam	2
# vocação	2
# vocemecê	2
# vociferar	1
# você	93
# vocês	52
# vogais	1
# voile	1
# voilà	4
# voir	1
# vola	1
# volantes	1
# volo	1
# volta	51
# voltada	2
# voltadas	1
# voltado	6
# voltam	2
# voltamos	1
# voltando	9
# voltandolhe	1
# voltandose	23
# voltar	40
# voltara	16
# voltaram	5
# voltaramse	2
# voltarase	3
# voltarete	3
# voltaretesinho	1
# voltaria	1
# voltariam	1
# voltariana	1
# voltarse	1
# voltas	6
# voltasse	4
# voltassem	1
# voltaste	1
# voltava	22
# voltavam	4
# voltavamlhe	1
# voltavamse	1
# volte	1
# volteando	1
# voltei	2
# volteime	1
# voltes	2
# voltigeuse	1
# volto	3
# voltou	42
# voltouse	32
# voltámos	1
# volume	8
# volumes	2
# voluntariamente	3
# voluntário	1
# voluptuosamente	3
# voluptuosidade	5
# voluptuosidades	2
# voluptuoso	1
# vomitado	1
# vomitar	1
# vomitarlhe	1
# vomito	1
# vontade	21
# voo	3
# voou	1
# voraz	1
# vos	12
# vossa	5
# vosso	1
# vossê	3
# voto	2
# votos	4
# vou	50
# voulezvous	1
# voulhe	1
# voume	5
# vous	11
# voute	1
# vovô	14
# voz	137
# vozeirão	6
# vozes	12
# vozinha	1
# vrai	1
# vulgares	1
# vulto	3
# vá	22
# válidos	1
# várzea	1
# várzeas	1
# vás	6
# váse	2
# vã	4
# vão	24
# vãos	3
# véspera	58
# vésperas	5
# véu	27
# véus	6
# vê	18
# vêem	14
# vêemse	1
# vêla	12
# vêlas	1
# vêlo	4
# vêlos	1
# vêm	2
# vês	4
# víamonos	1
# vício	5
# vícios	2
# vínhamos	1
# vírus	1
# vísceras	2
# vítima	2
# vítimas	1
# vôos	1
# vôtre	1
# wagon	5
# wagons	2
# wagonsalão	3
# waterproof	5
# whist	14
# xadresinho	2
# xadrez	5
# xadrezinho	1
# xairel	1
# xarope	1
# xv	3
# xícara	1
# yes	7
# you	2
# zangado	4
# zangar	3
# zangarse	1
# zangase	1
# zangava	1
# zangouse	2
# zangues	2
# zelava	1
# zelo	1
# zelosamente	1
# zeloso	1
# zinco	3
# zombarias	1
# zumbir	1
# zumzum	1
# zurzira	1
# zás	7
# Àquela	1
# Á	32
# África	10
# Águeda	1
# Ámen	1
# Ás	16
# Ásia	2
# Átomo	12
# Áustria	7
# Ça	2
# É	354
# Éclogas	1
# Éliseés	1
# És	5
# Êtesvous	1
# Ó	26
# Ópera	1
# Óptimo	1
# à	891
# àquela	26
# àquelas	1
# àquele	18
# àqueles	1
# às	2
# á	5
# ácida	1
# ádito	1
# ágeis	1
# água	71
# águar	1
# águaráz	1
# águas	20
# águias	1
# álbum	1
# álbuns	2
# álcoois	1
# álcool	2
# áleas	1
# árabe	5
# árabes	2
# ária	2
# árias	1
# árvore	6
# árvores	58
# ás	221
# áspera	4
# ásperas	2
# áspero	5
# ásperos	1
# átomo	6
# átomos	2
# ângulo	2
# ânsia	1
# ãããããah	2
# ça	2
# é	942
# ébanos	1
# écloga	2
# écrire	1
# égua	10
# éguas	5
# éguasita	2
# éo	3
# épinards	1
# época	1
# és	25
# ése	1
# éter	1
# été	2
# ênfase	1
# êtes	2
# êxtase	10
# êxtaseouse	1
# êxtases	1
# ía	33
# íamos	3
# íase	4
# ídolo	3
# ímpeto	4
# ímpia	2
# índia	19
# índios	1
# íntimo	37
# íntimos	9
# ó	10
# óculo	2
# óculos	5
# ódio	18
# ódios	1
# ódiosinho	1
# óleo	4
# ónibus	5
# ópera	3
# óperacómica	1
# óptimo	5
# órbita	1
# órgão	2
# últimos	16
# única	29
# único	22
# únicos	1
# úteis	4
# útero	1
# útil	7

# %% [markdown]
# ## Sorting
# The results are not sorted. Let's sort them by frequency (the words with higher occurrence first).

# %% [markdown]
# ### Mapper
# Complete with the code for the mapper.

# %%
# %%file mapper_sort.py
#!/usr/bin/env python

# to be completed

# import sys
import sys

max=10000

# input comes from STDIN (standard input)
for line in sys.stdin:
    # remove leading and trailing whitespace
    line = line.strip()
    # split the line into word and frequency
    word, freq = line.split('\t', 1)
    # output the frequency as the key and the word as the value
    print('%04d\t%s' % (max-int(freq), word))
# Out:
# Writing mapper_sort.py

# %% [markdown]
# ### Reducer

# %%
# %%file reducer_sort.py
#!/usr/bin/env python

# import sys
import sys

max=10000

# input comes from STDIN (standard input)
for line in sys.stdin:
    # remove leading and trailing whitespace
    line = line.strip()
    # split the line into word and frequency
    freq, word = line.split('\t', 1)
    # print the word and frequency (sthe secret is that the mapper gets the keys sorted by increasing order)
    print('%s\t%d' % (word, max-int(freq)))
# Out:
# Writing reducer_sort.py

# %% [markdown]
# ### Hadoop standalone mode execution

# %% [markdown]
# The output directory needs to be cleared...

# %%
# !rm -rf results_sort

# %% [markdown]
# #### Submitting the job
#
# The _hadoop_ command is used to submit the mapreduce job to the cluster...
#
# Note that the results from previous map reduce step are going to be the input for the sorting step.

# %%
# !hadoop jar /usr/local/hadoop-3.3.6/share/hadoop/tools/lib/hadoop-*streaming*.jar -files mapper_sort.py,reducer_sort.py -mapper mapper_sort.py -reducer reducer_sort.py -input results_words/part-* -output results_sort
# Out:
# 2023-09-20 14:51:06,183 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2023-09-20 14:51:06,365 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2023-09-20 14:51:06,365 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2023-09-20 14:51:06,392 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-09-20 14:51:06,692 INFO mapred.FileInputFormat: Total input files to process : 1
# 2023-09-20 14:51:06,722 INFO mapreduce.JobSubmitter: number of splits:1
# 2023-09-20 14:51:07,038 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local844281911_0001
# 2023-09-20 14:51:07,038 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2023-09-20 14:51:07,482 INFO mapred.LocalDistributedCacheManager: Localized file:/content/mapper_sort.py as file:/tmp/hadoop-root/mapred/local/job_local844281911_0001_c5961013-b57e-43eb-870f-ce5c62088cfd/mapper_sort.py
# 2023-09-20 14:51:07,518 INFO mapred.LocalDistributedCacheManager: Localized file:/content/reducer_sort.py as file:/tmp/hadoop-root/mapred/local/job_local844281911_0001_bea5f2f4-5a82-4807-9975-3101b53c4b0f/reducer_sort.py
# 2023-09-20 14:51:07,648 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2023-09-20 14:51:07,651 INFO mapreduce.Job: Running job: job_local844281911_0001
# 2023-09-20 14:51:07,657 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2023-09-20 14:51:07,660 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2023-09-20 14:51:07,672 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-09-20 14:51:07,672 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-09-20 14:51:07,815 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2023-09-20 14:51:07,825 INFO mapred.LocalJobRunner: Starting task: attempt_local844281911_0001_m_000000_0
# 2023-09-20 14:51:07,864 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-09-20 14:51:07,867 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-09-20 14:51:07,887 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-09-20 14:51:07,898 INFO mapred.MapTask: Processing split: file:/content/results_words/part-00000:0+252357
# 2023-09-20 14:51:07,916 INFO mapred.MapTask: numReduceTasks: 1
# 2023-09-20 14:51:07,989 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-09-20 14:51:07,989 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-09-20 14:51:07,989 INFO mapred.MapTask: soft limit at 83886080
# 2023-09-20 14:51:07,989 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-09-20 14:51:07,989 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-09-20 14:51:07,993 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-09-20 14:51:08,005 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_sort.py]
# 2023-09-20 14:51:08,011 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2023-09-20 14:51:08,014 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2023-09-20 14:51:08,014 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2023-09-20 14:51:08,015 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2023-09-20 14:51:08,015 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2023-09-20 14:51:08,016 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2023-09-20 14:51:08,017 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2023-09-20 14:51:08,018 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2023-09-20 14:51:08,018 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2023-09-20 14:51:08,018 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2023-09-20 14:51:08,019 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2023-09-20 14:51:08,020 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2023-09-20 14:51:08,059 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:08,059 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:08,060 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:08,067 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:08,108 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:08,181 INFO streaming.PipeMapRed: Records R/W=11665/1
# 2023-09-20 14:51:08,299 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-09-20 14:51:08,300 INFO streaming.PipeMapRed: mapRedFinished
# 2023-09-20 14:51:08,304 INFO mapred.LocalJobRunner:
# 2023-09-20 14:51:08,305 INFO mapred.MapTask: Starting flush of map output
# 2023-09-20 14:51:08,305 INFO mapred.MapTask: Spilling map output
# 2023-09-20 14:51:08,305 INFO mapred.MapTask: bufstart = 0; bufend = 317752; bufvoid = 104857600
# 2023-09-20 14:51:08,305 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26123708(104494832); length = 90689/6553600
# 2023-09-20 14:51:08,373 INFO mapred.MapTask: Finished spill 0
# 2023-09-20 14:51:08,389 INFO mapred.Task: Task:attempt_local844281911_0001_m_000000_0 is done. And is in the process of committing
# 2023-09-20 14:51:08,392 INFO mapred.LocalJobRunner: Records R/W=11665/1
# 2023-09-20 14:51:08,392 INFO mapred.Task: Task 'attempt_local844281911_0001_m_000000_0' done.
# 2023-09-20 14:51:08,401 INFO mapred.Task: Final Counters for attempt_local844281911_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=396587
# 		FILE: Number of bytes written=1146649
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=22673
# 		Map output records=22673
# 		Map output bytes=317752
# 		Map output materialized bytes=363104
# 		Input split bytes=90
# 		Combine input records=0
# 		Spilled Records=22673
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=419430400
# 	File Input Format Counters
# 		Bytes Read=254341
# 2023-09-20 14:51:08,401 INFO mapred.LocalJobRunner: Finishing task: attempt_local844281911_0001_m_000000_0
# 2023-09-20 14:51:08,401 INFO mapred.LocalJobRunner: map task executor complete.
# 2023-09-20 14:51:08,405 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2023-09-20 14:51:08,405 INFO mapred.LocalJobRunner: Starting task: attempt_local844281911_0001_r_000000_0
# 2023-09-20 14:51:08,415 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-09-20 14:51:08,415 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-09-20 14:51:08,416 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-09-20 14:51:08,474 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@14c3f3c4
# 2023-09-20 14:51:08,506 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-09-20 14:51:08,548 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2382574336, maxSingleShuffleLimit=595643584, mergeThreshold=1572499072, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-09-20 14:51:08,562 INFO reduce.EventFetcher: attempt_local844281911_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-09-20 14:51:08,622 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local844281911_0001_m_000000_0 decomp: 363100 len: 363104 to MEMORY
# 2023-09-20 14:51:08,627 INFO reduce.InMemoryMapOutput: Read 363100 bytes from map-output for attempt_local844281911_0001_m_000000_0
# 2023-09-20 14:51:08,632 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 363100, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->363100
# 2023-09-20 14:51:08,638 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2023-09-20 14:51:08,639 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2023-09-20 14:51:08,640 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2023-09-20 14:51:08,648 INFO mapred.Merger: Merging 1 sorted segments
# 2023-09-20 14:51:08,648 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 363093 bytes
# 2023-09-20 14:51:08,659 INFO mapreduce.Job: Job job_local844281911_0001 running in uber mode : false
# 2023-09-20 14:51:08,660 INFO mapreduce.Job:  map 100% reduce 0%
# 2023-09-20 14:51:08,695 INFO reduce.MergeManagerImpl: Merged 1 segments, 363100 bytes to disk to satisfy reduce memory limit
# 2023-09-20 14:51:08,695 INFO reduce.MergeManagerImpl: Merging 1 files, 363104 bytes from disk
# 2023-09-20 14:51:08,696 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2023-09-20 14:51:08,696 INFO mapred.Merger: Merging 1 sorted segments
# 2023-09-20 14:51:08,698 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 363093 bytes
# 2023-09-20 14:51:08,698 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2023-09-20 14:51:08,712 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reducer_sort.py]
# 2023-09-20 14:51:08,716 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-09-20 14:51:08,719 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2023-09-20 14:51:08,750 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:08,750 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:08,751 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:08,760 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:08,867 INFO streaming.PipeMapRed: Records R/W=9761/1
# 2023-09-20 14:51:08,893 INFO streaming.PipeMapRed: R/W/S=10000/2820/0 in:NA [rec/s] out:NA [rec/s]
# 2023-09-20 14:51:09,005 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-09-20 14:51:09,029 INFO streaming.PipeMapRed: mapRedFinished
# 2023-09-20 14:51:09,030 INFO mapred.Task: Task:attempt_local844281911_0001_r_000000_0 is done. And is in the process of committing
# 2023-09-20 14:51:09,033 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2023-09-20 14:51:09,034 INFO mapred.Task: Task attempt_local844281911_0001_r_000000_0 is allowed to commit now
# 2023-09-20 14:51:09,038 INFO output.FileOutputCommitter: Saved output of task 'attempt_local844281911_0001_r_000000_0' to file:/content/results_sort
# 2023-09-20 14:51:09,041 INFO mapred.LocalJobRunner: Records R/W=9761/1 > reduce
# 2023-09-20 14:51:09,041 INFO mapred.Task: Task 'attempt_local844281911_0001_r_000000_0' done.
# 2023-09-20 14:51:09,042 INFO mapred.Task: Final Counters for attempt_local844281911_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=1122827
# 		FILE: Number of bytes written=1764090
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=272
# 		Reduce shuffle bytes=363104
# 		Reduce input records=22673
# 		Reduce output records=22673
# 		Spilled Records=22673
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=17
# 		Total committed heap usage (bytes)=419430400
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=254337
# 2023-09-20 14:51:09,043 INFO mapred.LocalJobRunner: Finishing task: attempt_local844281911_0001_r_000000_0
# 2023-09-20 14:51:09,043 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2023-09-20 14:51:09,662 INFO mapreduce.Job:  map 100% reduce 100%
# 2023-09-20 14:51:09,662 INFO mapreduce.Job: Job job_local844281911_0001 completed successfully
# 2023-09-20 14:51:09,674 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=1519414
# 		FILE: Number of bytes written=2910739
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=22673
# 		Map output records=22673
# 		Map output bytes=317752
# 		Map output materialized bytes=363104
# 		Input split bytes=90
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=272
# 		Reduce shuffle bytes=363104
# 		Reduce input records=22673
# 		Reduce output records=22673
# 		Spilled Records=45346
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=17
# 		Total committed heap usage (bytes)=838860800
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=254341
# 	File Output Format Counters
# 		Bytes Written=254337
# 2023-09-20 14:51:09,674 INFO streaming.StreamJob: Output directory: results_sort

# %% [markdown]
# #### Checking the results
# The result is stored in directory results_sort.

# %%
# !head -10 results_sort/part-*
# Out:
# de	8311
# a	6736
# o	6615
# que	4986
# e	4533
# um	3026
# com	2794
# do	2571
# da	2202
# uma	2170
